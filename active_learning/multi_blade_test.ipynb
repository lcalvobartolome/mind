# %%
import sys
from multi_blade import MultiBlade

# %%
import copy
import logging
import pickle
from pathlib import Path
import time
from termcolor import colored
import pandas as pd
import numpy as np
from doc_selector import DocSelector
from scipy.sparse import csr_matrix, hstack, vstack
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.multiclass import OneVsRestClassifier
from termcolor import colored
from IPython.display import display, HTML, clear_output

# %%
blade = MultiBlade(
   model_path = "/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20",
    source_path="/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/source/corpus_rosie/passages/translated/df_1.parquet",
    lang = "ES",
    blade_state_path='/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/multi_blade_state_ES_trained.pkl'
)

# %%
df = pd.read_csv("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/df_docs_updated_ES.csv")
df[df.human_labeled==True]
# Out:
# /tmp/ipykernel_1008353/1555556115.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/df_docs_updated_ES.csv")
#                                                 lemmas_x_x   id_top  \
# 1        especial caso meduloblastomas desenlace relaci...        1
# 22403    proveedor_atención médica recomendar él leche_...    22403
# 41870    consumo_tabaco padre dañar salud niño familia ...    41870
# 48233    zobel hermano vivir tío familia long_island in...    48233
# 51523                                 herramienta_validada    51523
# ...                                                    ...      ...
# 1053335          tipo prueba genético tipo prueba genético  1053364
# 1053338  diagnosticar afta_afta frecuente significar ig...  1053367
# 1053389  síntoma grave síndrome vejiga doloroso afectar...  1053418
# 1053401  ultrasonido cráneo estudio producir dolor onda...  1053430
# 1053404  paludismo enfermedad grave persona grave mujer...  1053433
#
#                      doc_id  id_preproc  \
# 1        ES_490955_64059-16           1
# 22403    ES_721057_99151-14       22403
# 41870     ES_515156_64369-6       41870
# 48233    ES_816514_104975-3       48233
# 51523     ES_670984_7426-75       51523
# ...                     ...         ...
# 1053335   ES_298222_40937-9     1053364
# 1053338  ES_349351_42861-13     1053367
# 1053389  ES_617082_86765-10     1053418
# 1053401   ES_726143_99370-9     1053430
# 1053404  ES_208188_38467-18     1053433
#
#                                                 lemmas_x_y  \
# 1        especial caso meduloblastomas desenlace relaci...
# 22403    proveedor_atención médica recomendar u él lech...
# 41870    consumo_tabaco padre dañar salud niño familia ...
# 48233    zobel hermano vivir tío familia long_island in...
# 51523                                 herramienta_validada
# ...                                                    ...
# 1053335          tipo prueba genético tipo prueba genético
# 1053338  diagnosticar afta_afta frecuente significar ig...
# 1053389  síntoma grave síndrome vejiga doloroso afectar...
# 1053401  ultrasonido cráneo estudio producir dolor onda...
# 1053404  paludismo enfermedad grave persona grave mujer...
#
#                                                       text  len         label  \
# 1        Cada vez está más claro, en especial en el cas...   36  [1, 1, 0, 0]
# 22403    Si el proveedor de atención médica recomienda ...   50  [0, 1, 1, 0]
# 41870    “El consumo de tabaco por los padres daña la s...   22  [1, 1, 0, 0]
# 48233    Zobel y su hermano vivían con su tío y su fami...   67  [0, 0, 1, 0]
# 51523    Además, sin necesidad de emplear para ello her...    1  [0, 0, 0, 0]
# ...                                                    ...  ...           ...
# 1053335  ¿Cuáles son los tipos principales de pruebas g...    6  [1, 0, 0, 0]
# 1053338  ¿Cómo se diagnostican las aftas: Las aftas son...   15  [1, 0, 0, 0]
# 1053389  Estas son algunas maneras en que los síntomas ...   46  [1, 0, 1, 0]
# 1053401  \n- Ultrasonido del cráneo. Estudio que no pro...   33  [1, 1, 0, 0]
# 1053404  El paludismo puede ser una enfermedad muy grav...   24  [1, 1, 1, 0]
#
#          human_labeled
# 1                 True
# 22403             True
# 41870             True
# 48233             True
# 51523             True
# ...                ...
# 1053335           True
# 1053338           True
# 1053389           True
# 1053401           True
# 1053404           True
#
# [85 rows x 9 columns]

# %%
filtered_df = df[df['label'].apply(lambda x: x == '[0, 0, 0, 0]')]
filtered_df
# Out:
#                                                 lemmas_x_x   id_top  \
# 51523                                 herramienta_validada    51523
# 177820   inclinar_sentimiento idea posición decisión_in...   177824
# 479741   matriculado acceder participar ecoe_abandonar ...   479755
# 730227   hoja electrónico calcular_salario gastado_dine...   730246
# 812804                  reconocer importancia hombre mujer   812827
# 925470   obvio gluten alimentos panes rosca pan croissa...   925498
# 948370   género manfreda pertenecer familia asparagacea...   948398
# 1037943  discriminación sesgo atención médico home you_...  1037972
#
#                      doc_id  id_preproc  \
# 51523     ES_670984_7426-75       51523
# 177820   ES_233370_39176-40      177824
# 479741    ES_992415_8527-26      479755
# 730227     ES_94997_22083-0      730246
# 812804   ES_31805_10992-390      812827
# 925470   ES_936862_123473-5      925498
# 948370    ES_1057085_9955-2      948398
# 1037943    ES_38127_11391-0     1037972
#
#                                                 lemmas_x_y  \
# 51523                                 herramienta_validada
# 177820   inclinar_sentimiento idea posición decisión_in...
# 479741   matriculado acceder participar ecoe_abandonar ...
# 730227   use hoja electrónico calcular_salario gastado_...
# 812804                  reconocer importancia hombre mujer
# 925470   obvio gluten alimentos panes rosca pan croissa...
# 948370   género manfreda pertenecer familia asparagacea...
# 1037943  discriminación sesgo atención médico home you_...
#
#                                                       text  len         label  \
# 51523    Además, sin necesidad de emplear para ello her...    1  [0, 0, 0, 0]
# 177820   ¿Hacia qué se inclina ahora: Ahora que ha cons...    5  [0, 0, 0, 0]
# 479741   De los 113 matriculados, 102 accedieron a part...   13  [0, 0, 0, 0]
# 730227   Use esta hoja de trabajo electrónica para calc...   13  [0, 0, 0, 0]
# 812804   • Reconocer la importancia de las diferencias ...    4  [0, 0, 0, 0]
# 925470   Las fuentes obvias de gluten incluyen:\n- Alim...   23  [0, 0, 0, 0]
# 948370   El género Manfreda pertenece a la familia Aspa...   26  [0, 0, 0, 0]
# 1037943  Discriminación y sesgo en la atención médica H...   20  [0, 0, 0, 0]
#
#          human_labeled
# 51523             True
# 177820            True
# 479741            True
# 730227            True
# 812804            True
# 925470            True
# 948370            True
# 1037943           True

# %%
pred = blade.predict(path_save = "/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/df_docs_predicted_ES_multi.csv")

# %%
#blade.active_learning_loop(max_duration_minutes=1)
#blade.get_document(0)
#blade.do_update([1,0,1,0])

# %%
blade = MultiBlade(
   model_path = "/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20",
    source_path="/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/source/corpus_rosie/passages/translated/df_1.parquet",
    lang = "ES",
    blade_state_path='/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/multi_blade_state_ES_trained_test.pkl'
)

# %%
import pandas as pd
df = pd.read_parquet("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/source/corpus_rosie/passages/translated/df_1.parquet")
df
# Out:
#          id_preproc                                             lemmas  \
# 0                 0  order avoid future allergic_reaction range vom...
# 1                 1  author_affiliations shinyi_wu phd university s...
# 2                 2                             review_feb good doctor
# 3                 3  remove morning remove water balloon place syri...
# 4                 4  risk factor child diagnose mis_c age year old ...
# ...             ...                                                ...
# 1062898     1062898  compromiso hepático hepatoesplenomegalia alter...
# 1062899     1062899  glioma vía óptico tipo glioma_grado crecimient...
# 1062900     1062900  gustar_donación deducible_impuesto vanguardia_...
# 1062901     1062901  licencia_alquiler previo archivado encontrar v...
# 1062902     1062902  año edad estilo_vida activo_evalúar entrenamie...
#
#                                                  lemmas_tr  \
# 0        evitar futuro reacción_alérgico vómito urticar...
# 1        author_afiliations shinyi_wu phd university_of...
# 2                                   reviewed_on feb médico
# 3        quitar mañana quitar sacar agua globo coloquir...
# 4        factor_riesgo niño diagnosticado soler año eda...
# ...                                                    ...
# 1062898  liver involvement_hepatosplenomegaly liver pro...
# 1062899  optical_glioma low grade_glioma slow_growth oc...
# 1062900  tax_deductible donation_cut edge_research medi...
# 1062901  archive prior rental_license document verify d...
# 1062902  year_old active_lifestyle study evaluate effec...
#
#                        doc_id  \
# 0           EN_607595_99219-9
# 1          EN_183633_46512-40
# 2         EN_854328_122182-27
# 3         EN_1361170_297168-6
# 4        EN_1091308_196292-20
# ...                       ...
# 1062898     ES_34067_11078-56
# 1062899     ES_491927_64077-5
# 1062900     ES_408122_50072-0
# 1062901      ES_497507_4521-2
# 1062902     ES_598613_74745-3
#
#                                                       text  \
# 0        In order to avoid future allergic reactions – ...
# 1        Author Affiliations: Shinyi Wu, PhD, Universit...
# 2        Reviewed on Feb 24, 2023: He is a very good do...
# 3        Removing the catheter:\n- In the morning, remo...
# 4        Risk factors: Children diagnosed with MIS-C ar...
# ...                                                    ...
# 1062898  El compromiso hepático está dado, principalmen...
# 1062899  El glioma de la vía óptica es un tipo de gliom...
# 1062900  ¿Te gustaría hacer una donación deducible de i...
# 1062901  Si no hay una licencia de alquiler previa arch...
# 1062902  ¿Tiene usted entre 18 y 55 años de edad y no t...
#
#                                                    text_tr lang
# 0        Para evitar futuras reacciones alérgicas, que ...   EN
# 1        Author Afiliations: Shinyi Wu, PhD, University...   EN
# 2        Reviewed on Feb 24, 2023: Es un médico muy bueno.   EN
# 3        Quitar el catéter:\n- Por la mañana, quitar el...   EN
# 4        Factores de riesgo: Los niños diagnosticados c...   EN
# ...                                                    ...  ...
# 1062898  Liver involvement is mainly due to hepatosplen...   ES
# 1062899  Optical glioma is a type of low-grade glioma (...   ES
# 1062900  Would you like to make a tax-deductible donati...   ES
# 1062901  If there is no archived prior rental license: ...   ES
# 1062902  Are you between 18 and 55 years old and don't ...   ES
#
# [2456016 rows x 7 columns]
