# %% [markdown]
# # Results from Evaluating Rosie Corpus Documents

# %%
from blade import Blade
import pandas as pd

# %% [markdown]
# ## English Annotations (Audrey)

# %%
df = pd.read_csv("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/df_docs_updated_EN.csv")
labelled = df[df.human_labeled==True]

# %%
labelled.doc_id.unique().tolist()
# Out:
# ['EN_607595_99219-9',
#  'EN_563466_92637-16',
#  'EN_1177833_229387-3',
#  'EN_491917_79827-0',
#  'EN_52733_31571-15',
#  'EN_955009_164933-15',
#  'EN_1337984_292964-9',
#  'EN_1071979_192705-15',
#  'EN_246821_51270-14',
#  'EN_26631_26136-1',
#  'EN_665342_14582-4',
#  'EN_172773_7067-6',
#  'EN_816012_119872-15',
#  'EN_1090373_196191-6',
#  'EN_837047_16914-548',
#  'EN_399428_60500-20',
#  'EN_184278_46537-13',
#  'EN_60488_33505-98',
#  'EN_1148929_219106-3',
#  'EN_183953_46525-25',
#  'EN_162174_46277-56',
#  'EN_241744_50520-4',
#  'EN_605039_98788-30',
#  'EN_78706_35944-15',
#  'EN_162044_46272-12',
#  'EN_1366786_297761-1416',
#  'EN_51006_31387-3',
#  'EN_773076_115641-40',
#  'EN_32888_27074-2',
#  'EN_1026820_182451-7',
#  'EN_326925_54632-154',
#  'EN_550673_90735-0',
#  'EN_523810_86864-0',
#  'EN_379845_58098-1',
#  'EN_972891_166650-3',
#  'EN_209243_47526-35',
#  'EN_1375832_299206-0',
#  'EN_711430_110724-40',
#  'EN_186035_46613-12',
#  'EN_424709_63037-6',
#  'EN_1188861_250331-2',
#  'EN_906771_150355-7',
#  'EN_1030381_183394-0',
#  'EN_215851_48027-13',
#  'EN_405464_61252-11',
#  'EN_559570_92274-0',
#  'EN_896784_131752-19',
#  'EN_1003768_18831-2',
#  'EN_1323364_22289-122',
#  'EN_554986_91594-24',
#  'EN_1338079_292976-6',
#  'EN_304019_53607-152',
#  'EN_815168_119755-71',
#  'EN_906162_150236-10',
#  'EN_188206_46687-2',
#  'EN_1140350_210353-1',
#  'EN_1150407_219560-2',
#  'EN_1115721_203236-21',
#  'EN_906706_150338-6',
#  'EN_17946_24325-67',
#  'EN_1241158_280454-9',
#  'EN_690458_108625-25',
#  'EN_51081_31400-4',
#  'EN_366067_56528-10',
#  'EN_803344_118848-13',
#  'EN_293741_53346-36',
#  'EN_230940_49677-32',
#  'EN_892869_128801-15',
#  'EN_1001957_18524-66',
#  'EN_918377_152152-10',
#  'EN_226565_49167-11',
#  'EN_872801_124470-18',
#  'EN_907648_150569-1',
#  'EN_547705_90274-15',
#  'EN_470869_67353-10',
#  'EN_112737_42772-40',
#  'EN_199487_47108-20',
#  'EN_744434_113017-6',
#  'EN_1367740_297844-805',
#  'EN_971985_166525-12',
#  'EN_259882_52587-532',
#  'EN_1394652_301700-27',
#  'EN_1320609_22141-15',
#  'EN_977940_167039-2',
#  'EN_477669_69582-0',
#  'EN_1093277_196488-19',
#  'EN_18107_24338-63',
#  'EN_301502_53493-17',
#  'EN_519687_86430-2',
#  'EN_1199959_270595-0',
#  'EN_1368539_297907-4',
#  'EN_705650_110212-8',
#  'EN_1004194_18920-0',
#  'EN_990472_17423-25',
#  'EN_947865_158068-11',
#  'EN_1064682_190887-77',
#  'EN_623462_102922-1',
#  'EN_78319_35760-2',
#  'EN_1413785_305610-10',
#  'EN_411629_61908-3',
#  'EN_740978_112757-6',
#  'EN_672431_15574-69',
#  'EN_228606_49414-15',
#  'EN_660504_13541-0',
#  'EN_603896_98612-26',
#  'EN_747671_113358-26',
#  'EN_136772_44552-82',
#  'EN_1056651_189464-7',
#  'EN_1329103_22850-3',
#  'EN_288914_53282-49',
#  'EN_1002625_18579-11',
#  'EN_546473_89991-15',
#  'EN_1332994_23435-1',
#  'EN_145196_45724-22',
#  'EN_1052003_188619-4',
#  'EN_75448_34801-3',
#  'EN_949344_158364-17',
#  'EN_338340_9842-5',
#  'EN_937890_156152-1',
#  'EN_1333747_23600-23',
#  'EN_886968_127792-9',
#  'EN_356290_55558-5',
#  'EN_783464_116612-23',
#  'EN_1325900_22502-5',
#  'EN_407421_61508-10',
#  'EN_1383408_300598-2',
#  'EN_208716_47489-36',
#  'EN_1426264_308508-2',
#  'EN_540747_88990-0',
#  'EN_526610_87179-26',
#  'EN_221212_48506-28',
#  'EN_30343_26725-74',
#  'EN_33376_27176-10',
#  'EN_1029356_183113-0',
#  'EN_304088_53607-233',
#  'EN_264322_52643-123',
#  'EN_1031405_184399-12',
#  'EN_134625_44199-2',
#  'EN_572150_93597-4',
#  'EN_349002_54791-14',
#  'EN_1250812_281181-5',
#  'EN_1053165_188748-1',
#  'EN_892285_128676-6',
#  'EN_168698_4069-8',
#  'EN_574075_93909-21',
#  'EN_13365_1495-4',
#  'EN_311248_53674-95',
#  'EN_608851_99420-1',
#  'EN_507612_12563-2',
#  'EN_141330_45140-2',
#  'EN_194508_46912-32',
#  'EN_632544_104736-0',
#  'EN_1188149_249166-3',
#  'EN_90338_38588-1',
#  'EN_1030140_183322-2',
#  'EN_231321_49717-57',
#  'EN_147051_45783-28',
#  'EN_726277_111784-2',
#  'EN_311372_53675-115',
#  'EN_237522_50285-8',
#  'EN_218492_48231-5',
#  'EN_1059091_189714-6',
#  'EN_1190129_252277-0',
#  'EN_163393_46323-33',
#  'EN_1409707_305188-0',
#  'EN_227202_49241-69',
#  'EN_212965_47803-3',
#  'EN_905398_150124-17',
#  'EN_1086934_195804-10',
#  'EN_160781_46225-56',
#  'EN_1036029_185276-2',
#  'EN_631976_104625-20',
#  'EN_1124758_205844-2',
#  'EN_933061_155310-1',
#  'EN_569888_93165-1',
#  'EN_1086261_195648-0',
#  'EN_1286589_285226-4',
#  'EN_26994_26215-3',
#  'EN_1149597_219308-13',
#  'EN_189579_46734-33',
#  'EN_217117_48111-15',
#  'EN_317439_54014-29',
#  'EN_830473_16519-1',
#  'EN_1315830_291660-2',
#  'EN_219560_48359-12',
#  'EN_1020790_180894-1',
#  'EN_656296_107135-13',
#  'EN_773299_115654-34',
#  'EN_596153_97495-20',
#  'EN_54161_31908-22',
#  'EN_1201687_275281-5',
#  'EN_738263_112600-53',
#  'EN_140056_44928-50',
#  'EN_1021485_181022-7',
#  'EN_255809_52523-17',
#  'EN_193029_46862-20',
#  'EN_1372995_298640-5',
#  'EN_1078102_194176-5',
#  'EN_1403404_303124-21',
#  'EN_98791_39896-6',
#  'EN_624933_103307-4']

# %%
sixty_percent_size = int(len(labelled) * 0.6)

# Split the dataframe based on labels
positive_df = labelled[labelled['label'] == 1.0]
negative_df = labelled[labelled['label'] == 0.0]

# Determine the number of samples needed from each label to maintain balance
n_samples_per_label = int(half_size // 2)

print(n_samples_per_label)
# Out:
# 67

# %%
positive_sample = positive_df.sample(n=n_samples_per_label, random_state=1)
negative_sample = negative_df.sample(n=n_samples_per_label, random_state=1)

# Combine the sampled dataframes into one balanced dataframe
balanced_sample = pd.concat([positive_sample, negative_sample])

# Shuffle the combined dataframe
balanced_sample = balanced_sample.sample(frac=1, random_state=1).reset_index(drop=True)

balanced_sample
# Out:
#                                             lemmas_x_x   id_top
# 0    statistic tuberculosis case report national in...   785498  \
# 1    baby bump start clothe snug feel good energy m...   701886
# 2                 adventure tale leave pair twin place   501865
# 3    americans_disabilities act_ada prevent manager...   785598
# 4    regular cholesterol screening employee health ...  1188362
# ..                                                 ...      ...
# 129  comprehensive customize dedicate executive hea...  1118785
# 130  vaccine children safe terrorism october dan fa...     4133
# 131  baltimore_city health department_bchd view hea...   973893
# 132  encore_presentation national diabetes preventi...   760672
# 133  facilitate equitable efficient vaccine uptake ...   794251
#
#                   doc_id  id_preproc
# 0     EN_740978_112757-6      785498  \
# 1    EN_971985_166525-12      701886
# 2     EN_906706_150338-6      501865
# 3     EN_1329103_22850-3      785598
# 4      EN_830473_16519-1     1188362
# ..                   ...         ...
# 129  EN_1086261_195648-0     1118785
# 130    EN_491917_79827-0        4133
# 131     EN_90338_38588-1      973893
# 132   EN_1004194_18920-0      760672
# 133  EN_1002625_18579-11      794251
#
#                                             lemmas_x_y
# 0    statistic tuberculosis case report national in...  \
# 1    baby bump start clothe little snug feel good e...
# 2           adventure tale leave pair twin right place
# 3    americans_disabilities act_ada prevent manager...
# 4    regular cholesterol screening employee health ...
# ..                                                 ...
# 129  comprehensive customize dedicate executive hea...
# 130  vaccine help children safe terrorism october d...
# 131  baltimore_city health department_bchd view hea...
# 132  encore_presentation national diabetes preventi...
# 133  facilitate equitable efficient vaccine uptake ...
#
#                                                   text  len  label
# 0    Statistics show that there were 7,860 tubercul...    9    1.0  \
# 1    Your baby bump might be starting to show, and ...   15    1.0
# 2    An adventure tale leaves a pair of twins tempo...    7    0.0
# 3    3. The Americans with Disabilities Act of 1990...    9    1.0
# 4    Regular cholesterol screening for employees, a...   28    1.0
# ..                                                 ...  ...    ...
# 129  Comprehensive — customized — dedicated: Many E...   24    0.0
# 130  Using Vaccines to Help Keep Children Safe from...   15    0.0
# 131  The Baltimore City Health Department (BCHD) vi...   14    0.0
# 132  Encore Presentation, The National Diabetes Pre...   10    0.0
# 133  To facilitate equitable and efficient COVID-19...   85    1.0
#
#      human_labeled
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# ..             ...
# 129           True
# 130           True
# 131           True
# 132           True
# 133           True
#
# [134 rows x 9 columns]

# %% [markdown]
# ## Spanish Annotations (Valérie)

# %%
blade = Blade(
    model_path = "/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20",
    source_path="/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/source/corpus_rosie/passages/translated/df_1.parquet",
    lang = "ES",
    blade_state_path='/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/blade_state_ES_trained.pkl'
)

# %%
blade.df_docs
# Out:
#                                                 lemmas_x_x   id_top
# 0        causas interno oído contener célula_pilosa dim...        0  \
# 1        especial caso meduloblastomas desenlace relaci...        1
# 2        paciente glioma_difuso línea medio alteración ...        2
# 3        guía destinado facilitar coordinador utilícela...        3
# 4        recibir suspensión_liberación prolongado_azitr...        4
# ...                                                    ...      ...
# 1062869  compromiso hepático hepatoesplenomegalia alter...  1062898
# 1062870  glioma vía óptico tipo glioma_grado crecimient...  1062899
# 1062871  gustar_donación deducible_impuesto vanguardia_...  1062900
# 1062872  licencia_alquiler previo archivado encontrar v...  1062901
# 1062873  año edad estilo_vida activo_evalúar entrenamie...  1062902
#
#                       doc_id  id_preproc
# 0         ES_953747_124620-3           0  \
# 1         ES_490955_64059-16           1
# 2         ES_533943_64846-86           2
# 3          ES_44759_12033-16           3
# 4        ES_1012862_127780-5           4
# ...                      ...         ...
# 1062869    ES_34067_11078-56     1062898
# 1062870    ES_491927_64077-5     1062899
# 1062871    ES_408122_50072-0     1062900
# 1062872     ES_497507_4521-2     1062901
# 1062873    ES_598613_74745-3     1062902
#
#                                                 lemmas_x_y
# 0        causas interno oído contener célula_pilosa dim...  \
# 1        especial caso meduloblastomas desenlace relaci...
# 2        paciente glioma_difuso línea medio alteración ...
# 3        guía destinado facilitar coordinador utilícela...
# 4        recibir suspensión_liberación prolongado_azitr...
# ...                                                    ...
# 1062869  compromiso hepático hepatoesplenomegalia alter...
# 1062870  glioma vía óptico tipo glioma_grado crecimient...
# 1062871  gustar_donación deducible_impuesto vanguardia_...
# 1062872  licencia_alquiler previo archivado encontrar v...
# 1062873  año edad estilo_vida activo_evalúar entrenamie...
#
#                                                       text  len  label
# 0        Causas: La parte interna del oído contiene cél...   13    NaN  \
# 1        Cada vez está más claro, en especial en el cas...   36    1.0
# 2        Los pacientes con glioma difuso de línea media...    9    NaN
# 3        Esta guía está destinada a facilitar el trabaj...   24    NaN
# 4        Si recibe la suspensión de liberación prolonga...   34    NaN
# ...                                                    ...  ...    ...
# 1062869  El compromiso hepático está dado, principalmen...   15    NaN
# 1062870  El glioma de la vía óptica es un tipo de gliom...   11    NaN
# 1062871  ¿Te gustaría hacer una donación deducible de i...    5    NaN
# 1062872  Si no hay una licencia de alquiler previa arch...   15    NaN
# 1062873  ¿Tiene usted entre 18 y 55 años de edad y no t...   35    NaN
#
#          human_labeled
# 0                False
# 1                 True
# 2                False
# 3                False
# 4                False
# ...                ...
# 1062869          False
# 1062870          False
# 1062871          False
# 1062872          False
# 1062873          False
#
# [1062874 rows x 9 columns]

# %%
df = pd.read_csv("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/df_docs_updated_ES.csv")
df[df.human_labeled==True]
# Out:
#                                                 lemmas_x_x   id_top
# 1        especial caso meduloblastomas desenlace relaci...        1  \
# 2421     vacuna_varicela aplicar vacuna niño mes año re...     2421
# 22403    proveedor_atención médica recomendar él leche_...    22403
# 24752    analgésico_opioides soler inyectar él catéter ...    24752
# 27478    alimento cuerpo nutrient necesitar enseñar él ...    27478
# ...                                                    ...      ...
# 1053332  síntoma depender_gravedad lesión localización ...  1053361
# 1053356  descongele_leche materno colocar recipiente_re...  1053385
# 1053377  expectativas_pronóstico corona sentir él_cómod...  1053406
# 1053401  ultrasonido cráneo estudio producir dolor onda...  1053430
# 1053500  persona sistema_inmunitario debilitado riesgo ...  1053529
#
#                       doc_id  id_preproc
# 1         ES_490955_64059-16           1  \
# 2421       ES_243623_39453-6        2421
# 22403     ES_721057_99151-14       22403
# 24752     ES_464576_61791-16       24752
# 27478     ES_567801_66224-21       27478
# ...                      ...         ...
# 1053332   ES_853572_115720-1     1053361
# 1053356   ES_790109_103107-3     1053385
# 1053377  ES_963491_125277-16     1053406
# 1053401    ES_726143_99370-9     1053430
# 1053500   ES_973054_125990-6     1053529
#
#                                                 lemmas_x_y
# 1        especial caso meduloblastomas desenlace relaci...  \
# 2421     vacuna_varicela aplicar vacuna niño mes año re...
# 22403    proveedor_atención médica recomendar u él lech...
# 24752    analgésico_opioides soler inyectar él catéter ...
# 27478    alimento cuerpo nutrient necesitar enseñar él ...
# ...                                                    ...
# 1053332  síntoma depender_gravedad lesión localización ...
# 1053356  descongele_leche materno colocar recipiente_re...
# 1053377  expectativas_pronóstico corona sentir él_cómod...
# 1053401  ultrasonido cráneo estudio producir dolor onda...
# 1053500  persona sistema_inmunitario debilitado riesgo ...
#
#                                                       text  len  label
# 1        Cada vez está más claro, en especial en el cas...   36    1.0  \
# 2421     La vacuna contra la varicela se puede aplicar ...   19    0.0
# 22403    Si el proveedor de atención médica recomienda ...   50    1.0
# 24752    Los analgésicos, como los opioides, suelen iny...   26    1.0
# 27478    "Los alimentos le dan al cuerpo los nutrientes...   24    1.0
# ...                                                    ...  ...    ...
# 1053332  Los síntomas, que dependen de la gravedad de l...   32    1.0
# 1053356  Descongele la leche materna colocando el recip...    7    0.0
# 1053377  Expectativas (pronóstico): Cuando tiene una co...    7    0.0
# 1053401  \n- Ultrasonido del cráneo. Estudio que no pro...   33    1.0
# 1053500  Las personas con sistemas inmunitarios debilit...    7    1.0
#
#          human_labeled
# 1                 True
# 2421              True
# 22403             True
# 24752             True
# 27478             True
# ...                ...
# 1053332           True
# 1053356           True
# 1053377           True
# 1053401           True
# 1053500           True
#
# [192 rows x 9 columns]

# %%
pred = blade.predict(path_save = "/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/df_docs_predicted_ES.csv")

# %%
pred[pred.predicted_label==1]
# Out:
#           id_top                                               text
# 0              0  Causas: La parte interna del oído contiene cél...  \
# 4              5  Elija la protección ocular adecuada: Proteja s...
# 9             10  Cuando la crema de imiquimod se usa para trata...
# 42            43  Las parejas que ya tienen un bebé con este sín...
# 52            53  \n- Hidrocele comunicante. Un hidrocele comuni...
# ...          ...                                                ...
# 1062651  1062872  En la investigación sobre el uso de aceite de ...
# 1062654  1062875  ¿Para cuáles condiciones o enfermedades se pre...
# 1062667  1062888  Cocina más en casa: Preparar tus propias comid...
# 1062669  1062890  Estar activo es importante para cualquier prog...
# 1062670  1062891  Tome de 8 a 10 tazas (2 a 2.5 litros) de líqui...
#
#          predicted_label
# 0                      1
# 4                      1
# 9                      1
# 42                     1
# 52                     1
# ...                  ...
# 1062651                1
# 1062654                1
# 1062667                1
# 1062669                1
# 1062670                1
#
# [155234 rows x 3 columns]

# %%
pred[pred.predicted_label==0]
# Out:
#           id_top                                               text
# 1              2  Los pacientes con glioma difuso de línea media...  \
# 2              3  Esta guía está destinada a facilitar el trabaj...
# 3              4  Si recibe la suspensión de liberación prolonga...
# 5              6  Tal vez no te animes, pero no está mal que hab...
# 6              7  El procedimiento durará alrededor de 1 a 3 hor...
# ...          ...                                                ...
# 1062677  1062898  El compromiso hepático está dado, principalmen...
# 1062678  1062899  El glioma de la vía óptica es un tipo de gliom...
# 1062679  1062900  ¿Te gustaría hacer una donación deducible de i...
# 1062680  1062901  Si no hay una licencia de alquiler previa arch...
# 1062681  1062902  ¿Tiene usted entre 18 y 55 años de edad y no t...
#
#          predicted_label
# 1                      0
# 2                      0
# 3                      0
# 5                      0
# 6                      0
# ...                  ...
# 1062677                0
# 1062678                0
# 1062679                0
# 1062680                0
# 1062681                0
#
# [907448 rows x 3 columns]

# %%
#df_pred = pd.read_csv("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_10/df_docs_updated_EN.csv")
#df_pred
