# %% [markdown]
# # Results from Evaluating Rosie Corpus Documents

# %%
from blade import Blade
import pandas as pd

# %%
blade = Blade(
    model_path = "/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_10",
    source_path="/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/source/corpus_rosie/passages/translated/df_1.parquet",
    lang = "EN",
    blade_state_path='/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_10/blade_state_EN_trained.pkl'
)

# %%
blade.df_docs
# Out:
#                                                 lemmas_x_x   id_top
# 0        order avoid future allergic_reaction range vom...        0  \
# 1        author_affiliations shinyi_wu phd university s...        1
# 2                                   review_feb good doctor        2
# 3        remove morning remove water balloon place syri...        3
# 4        risk factor child diagnose mis_c age year case...        4
# ...                                                    ...      ...
# 1393092  overview photograph presence tumor vertebrae t...  1393108
# 1393093  pain bad day esi information technology begin ...  1393109
# 1393094  weaver parent promote healthy body image child...  1393110
# 1393095  choi_peter meyerson_matthew targeted genomic_r...  1393111
# 1393096  gardner_mm faerber_j preminger_t avitabile sha...  1393112
#
#                        doc_id  id_preproc
# 0           EN_607595_99219-9           0  \
# 1          EN_183633_46512-40           1
# ...

# %%
df = pd.read_csv("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_10/df_docs_updated_EN.csv")
df[df.human_labeled==True]
# Out:
#                                                 lemmas_x_x   id_top
# 0        order avoid future allergic_reaction range vom...        0  \
# 17536    student summer volunteer program johns_hopkins...    17536
# 66488    prophylactic_antimicrobial agent recommend tra...    66489
# 95647    half people diabete develop neuropathy informa...    95648
# 133279   doctor world health organization review x_ray ...   133280
# 144111   psychopharmacology clinic psychopharmacology c...   144112
# 159123    december minimum age purchase tobacco raise year   159124
# 189036   physician cardiac_catheterization laboratory i...   189037
# 212651   research add evidence genetic factor play key ...   212652
# 264575   student match map interactive match map clevel...   264577
# 277802   pediatric liver center fred_suzanne biesecker_...   277805
# 305667   newborn daily pattern baby daily pattern baby ...   305670
# 355588   physician_assistant michael gunson pa physicia...   355592
# ...

# %%
blade.predict()

# %%
df_pred = pd.read_csv("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_10/df_docs_updated_EN.csv")
df_pred
