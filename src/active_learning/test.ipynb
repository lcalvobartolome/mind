# %%
from blade import Blade


blade = Blade(
    model_path = "/Users/lbartolome/Documents/GitHub/LinQAForge/data/models/rosie_lg_lda_1_20",
    source_path="/Users/lbartolome/Documents/GitHub/LinQAForge/data/source/df_1.parquet",
    lang = "EN",
)
# Out:
# -- -- Loading source data from /Users/lbartolome/Documents/GitHub/LinQAForge/data/source/df_1.parquet...
# -- -- Loaded 1393113 documents...
# ...

# %%
blade.active_learning_loop()
# Out:
# Document ID: 994738
# Document Content: How do you fix a vaginal septum: You may not need treatment for a vaginal septum if it’s not causing any symptoms or affecting fertility. Your healthcare provider can discuss treatment with you, but in most cases, getting the septum surgically removed is the best option. This prevents complications during pregnancy and childbirth if you wish to have children in the future. There are instances when the septum tears naturally during sexual activity, and then, surgery isn’t needed.
# Document ID: 1200284
# Document Content: Any product labeled as organic on the product description or packaging must be USDA certified. If it's certified, the producer may also use an official USDA Organic seal.
# Document ID: 1189737
# Document Content: data for deaths by drug or drug class are unavailable.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ...
