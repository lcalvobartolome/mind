# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sentence_transformers import SentenceTransformer
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
from scipy import sparse
import pathlib
import os
from dotenv import load_dotenv
import time
import sys
import csv

csv.field_size_limit(100000000)
# Out:
# 131072

# %%
from langchain_core.documents import Document
from langchain_core.retrievers import BaseRetriever
from langchain_core.callbacks import CallbackManagerForRetrieverRun
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.llms import OpenAI
from langchain.chains import RetrievalQA, RetrievalQAWithSourcesChain
from langchain.document_loaders import TextLoader
from langchain.document_loaders import DirectoryLoader
from langchain.chat_models import ChatOpenAI
from langchain.docstore.document import Document
#from langchain_core.prompts import PromptTemplate
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI

# %% [markdown]
# ## OpenAI APIKEY

# %%
path_env = pathlib.Path(os.getcwd()).parent.parent / '.env'
load_dotenv(path_env)
api_key = os.getenv("OPENAI_API_KEY")

os.environ["OPENAI_API_KEY"] = api_key

# %% [markdown]
# ## Paths

# %%
path_orig_en = pathlib.Path("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/source/corpus_rosie/corpus_pass_en_tr.parquet")
path_orig_es = pathlib.Path("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/source/corpus_rosie/corpus_pass_es_tr.parquet")
path_source = pathlib.Path("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/source/corpus_rosie/passages/df_1.parquet")

path_model = pathlib.Path("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/LDA/passage/rosie_lg_lda_1_20")

path_corpus_en = path_model / "train_data" / "corpus_EN.txt"
path_corpus_es = path_model / "train_data" / "corpus_ES.txt"

persist_directory = (path_model / 'db_en_pred_test12').as_posix()

# %% [markdown]
# ## Read

# %%
raw_en = pd.read_parquet(path_source)
raw_en.head()
# Out:
#    id_preproc                                             lemmas  \
# 0           0  decrease initiation prevalence smoking hungary...
# 1           1  value add table calculated entrance_exit skin ...
# 2           2  outbreak duval_county begin april peak october...
# 3           3  broder rapid communication bethesda system rep...
# 4           4  opportunity meet social_worker child life spec...
#
#                 doc_id                                               text lang
# 0    EN_492297_60866-9  To decrease the initiation and prevalence of s...   EN
# 1  EN_143330_25224-123  Values added to Table 3-3; The calculated entr...   EN
# 2    EN_524864_63868-2  The outbreak in Duval County began in April 19...   EN
# 3   EN_518687_63341-14  Broder S. Rapid communication: the Bethesda Sy...   EN
# 4    EN_569477_70415-6  You will have the opportunity to meet with our...   EN

# %%
raw_en.columns
# Out:
# Index(['id_preproc', 'lemmas', 'doc_id', 'text', 'lang'], dtype='object')

# %%
with path_corpus_en.open("r", encoding="utf-8") as f:
    lines = [line for line in f.readlines()]
corpus_en = [line.rsplit(" 0 ")[1].strip().split() for line in lines]

ids = [line.split(" 0 ")[0] for line in lines]
df_en = pd.DataFrame({"lemmas": [" ".join(doc) for doc in corpus_en]})
df_en["doc_id"] = ids
df_en["len"] = df_en['lemmas'].apply(lambda x: len(x.split()))
df_en["id_top"] = range(len(df_en))

# %%
#corpus_en[0]

# %%
df_en_raw = df_en.merge(raw_en, how="inner", on="doc_id")[["doc_id", "id_top", "id_preproc", "lemmas_x", "text", "len"]]
df_en_raw
# Out:
#                        doc_id   id_top  id_preproc  \
# 0           EN_492297_60866-9        0           0
# 1         EN_143330_25224-123        1           1
# 2           EN_524864_63868-2        2           2
# 3          EN_518687_63341-14        3           3
# 4           EN_569477_70415-6        4           4
# ...                       ...      ...         ...
# 1393108     EN_485225_59974-3  1393108     1393108
# 1393109  EN_1219267_277263-11  1393109     1393109
# 1393110  EN_1238215_279154-29  1393110     1393110
# 1393111     EN_321620_48080-1  1393111     1393111
# 1393112    EN_401345_53381-49  1393112     1393112
#
#                                                   lemmas_x  \
# 0        decrease initiation prevalence smoking hungary...
# 1        value add table calculated entrance_exit skin ...
# 2        outbreak duval_county begin april peak october...
# 3        broder rapid communication bethesda system rep...
# 4        opportunity meet social_worker child life spec...
# ...                                                    ...
# 1393108  acip cdc determine priority group rank_tier ba...
# 1393109  surgical lie operating table intravenous_intra...
# 1393110  cure rate people stage tumor people stage intr...
# 1393111  suggested_citation article schneider kl lapane...
# 1393112  tetravalent_meningococcal conjugate_vaccine me...
#
#                                                       text  len
# 0        To decrease the initiation and prevalence of s...   63
# 1        Values added to Table 3-3; The calculated entr...   61
# 2        The outbreak in Duval County began in April 19...   58
# 3        Broder S. Rapid communication: the Bethesda Sy...   13
# 4        You will have the opportunity to meet with our...    9
# ...                                                    ...  ...
# 1393108  ACIP and CDC determined the priority groups, r...   61
# 1393109  For a surgical biopsy:\n- You'll lie on an ope...   53
# 1393110  The cure rates for people with stage III tumor...   11
# 1393111  Suggested citation for this article: Schneider...   21
# 1393112  MCV4 is a tetravalent meningococcal conjugate ...   23
#
# [1393113 rows x 6 columns]

# %%
# Read thetas 
thetas = sparse.load_npz(path_model.joinpath(f"mallet_output/{'EN'}/thetas.npz")).toarray()
betas = np.load((path_model.joinpath(f"mallet_output/{'EN'}/betas.npy")))
def get_thetas_str(row,thetas):
    return " ".join([f"{id_}|{round(el, 4)}" for id_,el in enumerate(thetas[row]) if el!=0.0])

def get_most_repr_tpc(row,thetas):
    return np.argmax(thetas[row])

df_en_raw["thetas"] = df_en_raw.apply(lambda row: get_thetas_str(row['id_top'], thetas), axis=1)
df_en_raw["id_tpc"] = df_en_raw.apply(lambda row: get_most_repr_tpc(row['id_top'], thetas), axis=1)

# %%
df_en_raw.head()
# Out:
#                 doc_id  id_top  id_preproc  \
# 0    EN_492297_60866-9       0           0
# 1  EN_143330_25224-123       1           1
# 2    EN_524864_63868-2       2           2
# 3   EN_518687_63341-14       3           3
# 4    EN_569477_70415-6       4           4
#
#                                             lemmas_x  \
# 0  decrease initiation prevalence smoking hungary...
# 1  value add table calculated entrance_exit skin ...
# 2  outbreak duval_county begin april peak october...
# 3  broder rapid communication bethesda system rep...
# 4  opportunity meet social_worker child life spec...
#
#                                                 text  len  \
# 0  To decrease the initiation and prevalence of s...   63
# 1  Values added to Table 3-3; The calculated entr...   61
# 2  The outbreak in Duval County began in April 19...   58
# 3  Broder S. Rapid communication: the Bethesda Sy...   13
# 4  You will have the opportunity to meet with our...    9
#
#                                               thetas  id_tpc
# 0  1|0.30140000581741333 6|0.04839999973773956 10...      10
# 1  3|0.08810000121593475 7|0.45579999685287476 11...       7
# 2  1|0.22429999709129333 15|0.7408999800682068 17...      15
# 3  4|0.22939999401569366 6|0.004100000020116568 1...      19
# 4  4|0.0035000001080334187 6|0.005900000222027302...      14

# %% [markdown]
# ## Merge with preds

# %%
df_pred = pd.read_csv("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/df_docs_predicted_EN.csv")
df_pred
# Out:
#                                                 lemmas_x_x   id_top  \
# 0        order avoid future allergic_reaction range vom...        0
# 1        author_affiliations shinyi_wu phd university s...        1
# 2                                   review_feb good doctor        2
# 3        remove morning remove water balloon place syri...        3
# 4        risk factor child diagnose mis_c age year case...        4
# ...                                                    ...      ...
# 1393092  overview photograph presence tumor vertebrae t...  1393108
# 1393093  pain bad day esi information technology begin ...  1393109
# 1393094  weaver parent promote healthy body image child...  1393110
# 1393095  choi_peter meyerson_matthew targeted genomic_r...  1393111
# 1393096  gardner_mm faerber_j preminger_t avitabile sha...  1393112
#
#                        doc_id  id_preproc  \
# 0           EN_607595_99219-9           0
# 1          EN_183633_46512-40           1
# 2         EN_854328_122182-27           2
# 3         EN_1361170_297168-6           3
# 4        EN_1091308_196292-20           4
# ...                       ...         ...
# 1393092   EN_1292789_287135-0     1393108
# 1393093   EN_771214_115470-28     1393109
# 1393094     EN_595076_97282-3     1393110
# 1393095    EN_629755_104139-9     1393111
# 1393096    EN_564069_92661-91     1393112
#
#                                                 lemmas_x_y  \
# 0        order avoid future allergic_reaction range vom...
# 1        author_affiliations shinyi_wu phd university s...
# 2                                   review_feb good doctor
# 3        remove morning remove water balloon place syri...
# 4        risk factor child diagnose mis_c age year old ...
# ...                                                    ...
# 1393092  overview photograph presence tumor vertebrae t...
# 1393093  pain bad day esi information technology begin ...
# 1393094  ask weaver parent promote healthy body image c...
# 1393095  choi_peter s meyerson_matthew targeted genomic...
# 1393096  gardner_mm faerber_j preminger_t avitabile c s...
#
#                                                       text  len  label  \
# 0        In order to avoid future allergic reactions – ...   24    1.0
# 1        Author Affiliations: Shinyi Wu, PhD, Universit...   18    0.0
# 2        Reviewed on Feb 24, 2023: He is a very good do...    3    1.0
# 3        Removing the catheter:\n- In the morning, remo...   41    1.0
# 4        Risk factors: Children diagnosed with MIS-C ar...   17    1.0
# ...                                                    ...  ...    ...
# 1393092  Overview: This photograph shows the presence o...   11    1.0
# 1393093  Your pain may become worse for two to three da...   16    1.0
# 1393094  We asked Dr. Weaver how parents can promote he...  108    1.0
# 1393095  2014: Choi Peter S, Meyerson Matthew: Targeted...    9    0.0
# 1393096  Gardner MM, Faerber J, Preminger T, Avitabile ...   32    0.0
#
#          human_labeled  predicted_label
# 0                 True              NaN
# 1                False              0.0
# 2                False              1.0
# 3                False              1.0
# 4                False              1.0
# ...                ...              ...
# 1393092          False              1.0
# 1393093          False              1.0
# 1393094          False              1.0
# 1393095          False              0.0
# 1393096          False              0.0
#
# [1393097 rows x 10 columns]

# %%
df_keep = df_pred[(df_pred.label == 1.0) | (df_pred.predicted_label == 1.0)]
df_keep
# Out:
#                                                 lemmas_x_x   id_top  \
# 0        order avoid future allergic_reaction range vom...        0
# 2                                   review_feb good doctor        2
# 3        remove morning remove water balloon place syri...        3
# 4        risk factor child diagnose mis_c age year case...        4
# 5        impact year single mom kid home schooling info...        5
# ...                                                    ...      ...
# 1393088  comprises_dose diphtheria_tetanus toxoid_pertu...  1393104
# 1393089  work good treatment talk pediatrician infant b...  1393105
# 1393092  overview photograph presence tumor vertebrae t...  1393108
# 1393093  pain bad day esi information technology begin ...  1393109
# 1393094  weaver parent promote healthy body image child...  1393110
#
#                        doc_id  id_preproc  \
# 0           EN_607595_99219-9           0
# 2         EN_854328_122182-27           2
# 3         EN_1361170_297168-6           3
# 4        EN_1091308_196292-20           4
# 5         EN_955188_164961-11           5
# ...                       ...         ...
# 1393088    EN_405733_61282-13     1393104
# 1393089    EN_915674_151728-5     1393105
# 1393092   EN_1292789_287135-0     1393108
# 1393093   EN_771214_115470-28     1393109
# 1393094     EN_595076_97282-3     1393110
#
#                                                 lemmas_x_y  \
# 0        order avoid future allergic_reaction range vom...
# 2                                   review_feb good doctor
# 3        remove morning remove water balloon place syri...
# 4        risk factor child diagnose mis_c age year old ...
# 5        impact year single mom kid home schooling info...
# ...                                                    ...
# 1393088  comprises_dose diphtheria_tetanus toxoid_pertu...
# 1393089  work good treatment talk pediatrician infant b...
# 1393092  overview photograph presence tumor vertebrae t...
# 1393093  pain bad day esi information technology begin ...
# 1393094  ask weaver parent promote healthy body image c...
#
#                                                       text  len  label  \
# 0        In order to avoid future allergic reactions – ...   24    1.0
# 2        Reviewed on Feb 24, 2023: He is a very good do...    3    1.0
# 3        Removing the catheter:\n- In the morning, remo...   41    1.0
# 4        Risk factors: Children diagnosed with MIS-C ar...   17    1.0
# 5        How has COVID-19 impacted you personally and p...   37    1.0
# ...                                                    ...  ...    ...
# 1393088  § Comprises >4 doses of diphtheria and tetanus...   30    1.0
# 1393089  If that doesn’t work, what are the best treatm...   23    1.0
# 1393092  Overview: This photograph shows the presence o...   11    1.0
# 1393093  Your pain may become worse for two to three da...   16    1.0
# 1393094  We asked Dr. Weaver how parents can promote he...  108    1.0
#
#          human_labeled  predicted_label
# 0                 True              NaN
# 2                False              1.0
# 3                False              1.0
# 4                False              1.0
# 5                False              1.0
# ...                ...              ...
# 1393088          False              1.0
# 1393089          False              1.0
# 1393092          False              1.0
# 1393093          False              1.0
# 1393094          False              1.0
#
# [985225 rows x 10 columns]

# %%
df_keep_ = df_keep.merge(df_en_raw, how="inner", on="id_top")
df_keep_ = df_keep_.loc[:, ~df_keep_.columns.str.endswith('_y')]
df_keep_.columns = df_keep_.columns.str.replace('_x', '')  # Remove '_x' suffix
df_keep_
# Out:
#                                                    lemmas   id_top  \
# 0       order avoid future allergic_reaction range vom...        0
# 1                                  review_feb good doctor        2
# 2       remove morning remove water balloon place syri...        3
# 3       risk factor child diagnose mis_c age year case...        4
# 4       impact year single mom kid home schooling info...        5
# ...                                                   ...      ...
# 985220  comprises_dose diphtheria_tetanus toxoid_pertu...  1393104
# 985221  work good treatment talk pediatrician infant b...  1393105
# 985222  overview photograph presence tumor vertebrae t...  1393108
# 985223  pain bad day esi information technology begin ...  1393109
# 985224  weaver parent promote healthy body image child...  1393110
#
#                       doc_id  id_preproc  \
# 0          EN_607595_99219-9           0
# 1        EN_854328_122182-27           2
# 2        EN_1361170_297168-6           3
# 3       EN_1091308_196292-20           4
# 4        EN_955188_164961-11           5
# ...                      ...         ...
# 985220    EN_405733_61282-13     1393104
# 985221    EN_915674_151728-5     1393105
# 985222   EN_1292789_287135-0     1393108
# 985223   EN_771214_115470-28     1393109
# 985224     EN_595076_97282-3     1393110
#
#                                                      text  len  label  \
# 0       In order to avoid future allergic reactions – ...   24    1.0
# 1       Reviewed on Feb 24, 2023: He is a very good do...    3    1.0
# 2       Removing the catheter:\n- In the morning, remo...   41    1.0
# 3       Risk factors: Children diagnosed with MIS-C ar...   17    1.0
# 4       How has COVID-19 impacted you personally and p...   37    1.0
# ...                                                   ...  ...    ...
# 985220  § Comprises >4 doses of diphtheria and tetanus...   30    1.0
# 985221  If that doesn’t work, what are the best treatm...   23    1.0
# 985222  Overview: This photograph shows the presence o...   11    1.0
# 985223  Your pain may become worse for two to three da...   16    1.0
# 985224  We asked Dr. Weaver how parents can promote he...  108    1.0
#
#         human_labeled  predicted_label  \
# 0                True              NaN
# 1               False              1.0
# 2               False              1.0
# 3               False              1.0
# 4               False              1.0
# ...               ...              ...
# 985220          False              1.0
# 985221          False              1.0
# 985222          False              1.0
# 985223          False              1.0
# 985224          False              1.0
#
#                                                    lemmas  \
# 0       decrease initiation prevalence smoking hungary...
# 1       outbreak duval_county begin april peak october...
# 2       broder rapid communication bethesda system rep...
# 3       opportunity meet social_worker child life spec...
# 4                           sexual_orientation feel fluid
# ...                                                   ...
# 985220                      review_jan continue recommend
# 985221  acknowledgment amob_vll major program activity...
# 985222  acip cdc determine priority group rank_tier ba...
# 985223  surgical lie operating table intravenous_intra...
# 985224  cure rate people stage tumor people stage intr...
#
#                                                    thetas  id_tpc
# 0       1|0.30140000581741333 6|0.04839999973773956 10...      10
# 1       1|0.22429999709129333 15|0.7408999800682068 17...      15
# 2       4|0.22939999401569366 6|0.004100000020116568 1...      19
# 3       4|0.0035000001080334187 6|0.005900000222027302...      14
# 4       0|0.005100000184029341 1|0.2888000011444092 2|...      12
# ...                                                   ...     ...
# 985220  0|0.005100000184029341 1|0.0066999997943639755...       6
# 985221  1|0.015300000086426735 10|0.47769999504089355 ...      13
# 985222                                             15|1.0      15
# 985223  0|0.0203000009059906 8|0.04039999842643738 12|...      12
# 985224  6|0.004800000227987766 9|0.003599999938160181 ...      17
#
# [985225 rows x 12 columns]

# %%
# Filter thetas by df_keep
df_keep_idx_set = set(df_keep.id_top.values.tolist())

# Create a mask where True indicates the index is in df_keep_idx_set
mask = np.array([i in df_keep_idx_set for i in range(thetas.shape[0])])

# Create a copy of thetas
thetas_ = thetas.copy()

# Set values to 0 where the mask is False
thetas_[~mask, :] = 0
thetas_.shape
# Out:
# (1393113, 20)

# %%
# Load vocab dictionaries
vocab_w2id = {}
vocab_id2w = {}

# Open the file and read the lines
with open((path_model / "mallet_output/EN" / "vocab_freq.txt"), 'r', encoding='utf8') as file:
    for i, line in enumerate(file):
        # Strip leading and trailing whitespace
        stripped_line = line.strip()
        # Split the line into words and numbers
        parts = stripped_line.split()
        if parts:
            # Get the word (first part)
            wd = parts[0]
            # Populate the dictionaries
            vocab_w2id[wd] = i
            vocab_id2w[str(i)] = wd

# %% [markdown]
# ## Topics

# %%
# Load topic-keys
keys = []
with open((path_model / "mallet_output/EN" / "topickeys.txt"), 'r') as file:
    for line in file:
        # Strip leading and trailing whitespace
        stripped_line = line.strip()
        # Split the line into parts and ignore the first two parts (number and float)
        parts = stripped_line.split(maxsplit=2)
        if len(parts) > 2:
            text_part = parts[2]
            keys.append(text_part)

# %%
keys
# Out:
# ['test heart doctor_begin blood disease image doctor technology lung information procedure magnetic_resonance imaging diagnose surgery result provider body ultrasound condition',
#  'age year high rate report health student death prevalence increase world organization state woman white adult person black population group',
#  'food eat water outbreak product information people report healthy illness diet include ill store animal source drink technology fda day',
#  'information technology skin symptom infection child people body common area severe bacteria treatment include condition treat pain day spread eye',
#  'case infection patient health hiv test report person tuberculosis world disease organization testing laboratory result cdc virus risk treatment transmission',
#  'medication information technology treatment medicine doctor drug treat symptom effect dose day prescribe pain provider time stop healthcare_provider talk child',
#  'information technology child time family good health day parent world people work question feel thing organization doctor talk year life',
#  'worker work exposure safety injury niosh information victim equipment include incident health fire area employee hazard technology system air occupational',
#  'research medical program hospital medicine pediatric clinical center university health year school care national children education training nationwide_children director children_hospital',
#  'health risk disease child people world organization condition diabetes high adult chronic factor disorder symptom increase treatment age problem study',
#  'health program community public state support include prevention information intervention cdc improve policy research work strategy organization school develop effort',
#  'datum report study survey estimate include analysis population year state participant health base number rate age information group measure level',
#  'surgery technology information pain procedure bone eye child injury muscle treatment remove surgeon body problem place condition small tissue time',
#  'health cdc center public national department prevention md report control state disease university phd office division new_york program human_services dept',
#  'care health patient child medical hospital organization world service provider family team visit treatment program center include physician plan information',
#  'vaccine vaccination influenza child age year dose report health world case organization virus person receive month vaccinate country risk increase',
#  'cell protein gene body information technology call blood condition disorder genetic function disease brain affect syndrome mutation form result normal',
#  'cancer treatment patient mayo_clinic study transplant tumor cell therapy research disease surgery treat lung breast_cancer doctor clinic liver clinical_trial center',
#  'pregnancy baby woman birth infant health risk information technology world organization pregnant mother week age control care increase fetal delivery',
#  'pediatric view_pubmed patient pubmed suggested_citation study disease article journal clinical child icon philadelphia_pa med dis association united_states outcome management mmwr_morb']

# %% [markdown]
# ## Create VectorDB for each topic

# %%
# Create a text splitter with specified chunk size and overlap
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)

# Select topic to analyze
topic = 18
df_topic = df_keep_[df_keep_.id_tpc == topic]

# Create documents and split them into chunks
#documents = [
#    Document(page_content=chunk, metadata={"url": "local", "source": "initial", "identifier": row['doc_id'], "id_top": row["id_top"]})
#    for idx, row in df_topic.iterrows()
#    for chunk in text_splitter.split_text(row['text'])
#]

# Get most representative document for that topic and assume it is free of contradictions
thetas_topic = thetas.T[topic]
top_doc_topic = np.argsort(thetas_topic)[::-1][0]
df_topic_doc = df_topic[df_topic.id_top == top_doc_topic]

# Create Langchain document for that doc
documents = [
    Document(page_content=chunk, metadata={"identifier": row['doc_id'], "source": row["id_top"]})
    for idx, row in df_topic_doc.iterrows()
    for chunk in text_splitter.split_text(row['text'])
]

# %%
np.argsort(thetas_topic)[::-1][0]
# Out:
# 921550

# %%
df_topic_doc.text
# Out:
# 651670    Don't forget that children with ASD have the s...
# Name: text, dtype: object

# %%
documents
# Out:
# [Document(page_content="Don't forget that children with ASD have the same healthcare needs as any other child and benefit from the same healthcare and disease prevention services. Accessing healthcare services can be challenging for children with autism because of communication barriers and sensory sensitivities. Preparation and planning help make medical visits more familiar and comfortable for children and their caregivers. As children with autism learn to cooperate with medical visits, they are better able to participate in healthy living and they build trust with their healthcare providers that impacts their overall health for their lifetime. Children’s National has a variety of visual supports and other resources to help families prepare and plan for medical visits.", metadata={'identifier': 'EN_474213_67961-3', 'source': 921550})]

# %%
start = time.time()
# Define embeddings
embedding = OpenAIEmbeddings()

# Create vector database with this document
vectorstore = Chroma.from_documents(
    documents=documents,
    embedding=embedding,
    persist_directory=persist_directory 
)
# Tiempo total de ejecución, tarda 51 mins en 300k docs
end = time.time()
print(f"Total time is {end - start} seconds")
# Out:
# Total time is 0.5859715938568115 seconds

# %% [markdown]
# Faithfulness: Choose one of the following options:
#
# True: No contradiction or discrepancy.
# Minor Discrepancy: A minor inconsistency that does not change the overall meaning. Examples include slight wording differences or small factual errors that do not affect the main message.
# Major Discrepancy: A significant inconsistency that alters the meaning or could mislead. Examples include notable factual errors or significant shifts in focus that change the context or understanding.
# Direct Contradiction: A direct and clear opposition to the context, making both statements impossible to be true simultaneously.
# Not Applicable: If the CONTEXT and TEXT are about entirely different topics, there is no inconsistency.

# %%
prompt_template_text = """
Identify if there are contradictions with the provided context.

CONTEXT: {summaries}

TEXT: {question}

---

Follow the following format.

Faithfulness: One of the following:
- True: There is a direct and clear opposition to the context.
- False: No contradiction or the new text is not relevant to the context provided.
Rationale: Why the new text contradicts the context or not
Type: One of the following
- Minor Discrepancy: A minor inconsistency that does not change the overall meaning. Examples include slight wording differences or small factual errors that do not affect the main message.
- Major Discrepancy: A significant inconsistency that alters the meaning or could mislead. Examples include notable factual errors or significant shifts in focus that change the context or understanding.
- Direct Contradiction: A direct and clear opposition to the context, making both statements impossible to be true simultaneously.
- N/A
Ids_contradiction: List with the 'source' of the documents in which the contradictions were found
---
"""
prompt_template = PromptTemplate.from_template(template=prompt_template_text)

# %%
# Set up the turbo LLM
llm = ChatOpenAI(
    temperature=0,
    model_name='gpt-3.5-turbo'
)

# Define retriever
nb_retrieval_docs = 5
retriever = vectorstore.as_retriever(
    search_kwargs={"k": nb_retrieval_docs}
)

# Crear la chain
chain = RetrievalQAWithSourcesChain.from_chain_type(
    llm=llm,
    retriever=retriever,
    chain_type="stuff",
    verbose=False,
    chain_type_kwargs={
        "verbose": False,
        "prompt": prompt_template
    }
)

# %%
df_topic.iloc[0].text
# Out:
# 'One thing’s for sure: Visceral pain isn’t “all in your head." But it is a little bit. That makes it trickier to target than a mechanical problem, but it also gives you some power. By activating the power of your brain, you can work to change your own neural pathways to reduce pain.'

# %%
retriever.get_relevant_documents(df_topic.iloc[0].text)
# Out:
# /home/lbartolome/.local/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# Number of requested results 5 is greater than number of elements in index 1, updating n_results = 1
# [Document(page_content="Don't forget that children with ASD have the same healthcare needs as any other child and benefit from the same healthcare and disease prevention services. Accessing healthcare services can be challenging for children with autism because of communication barriers and sensory sensitivities. Preparation and planning help make medical visits more familiar and comfortable for children and their caregivers. As children with autism learn to cooperate with medical visits, they are better able to participate in healthy living and they build trust with their healthcare providers that impacts their overall health for their lifetime. Children’s National has a variety of visual supports and other resources to help families prepare and plan for medical visits.", metadata={'identifier': 'EN_474213_67961-3', 'source': 921550})]

# %%
"""
import pickle
with open('non_consistent.pkl', 'wb') as file:
    pickle.dump(non_consistent, file)
"""
# Out:
# "\nimport pickle\nwith open('non_consistent.pkl', 'wb') as file:\n    pickle.dump(non_consistent, file)\n"

# %%
#non_consistent[17]

# %%
print(df_topic[df_topic.doc_id=="EN_1347456_294495-14"].text.values[0])
print("\n######\n")
print(df_topic[df_topic.id_top==765831].text.values[0])
# Out:
# IBS can be painful, but it doesn’t lead to other health problems or damage the digestive tract.
#
# ######
#
# Luckily, diarrhea is usually short-lived, lasting no more than a few days. But when diarrhea lasts beyond a few days into weeks, it usually indicates that there's another problem — such as irritable bowel syndrome (IBS) or a more serious disorder, including persistent infection, celiac disease or inflammatory bowel disease (IBD).

# %%
results = []
for index, row in df_topic.sample(n=1000, random_state=1).iterrows():
    if index % 100 == 0:
        print(f"-- -- Processed index {index / len(df_topic)}")
    d_response = chain({"question": row.text})
    #print(d_response)
    try:
        faithfulness = d_response["answer"].split("Faithfulness: ")[1].split("Rationale")[0].strip()
        rationale = d_response["answer"].split("Rationale: ")[1].strip().split("Type")[0].strip()
        type_ = d_response["answer"].split("Type: ")[1].strip().split("Ids_contradiction")[0].strip()
        Ids_contradiction = d_response["answer"].split("Ids_contradiction: ")[1].strip()
    except:
        import pdb; pdb.set_trace()
    
    if faithfulness == "False":
        vectorstore.add_documents([Document(page_content=row['text'], metadata={"identifier": row['doc_id'], "source": row["id_top"]})])
    results.append([row.doc_id, faithfulness, rationale,type_, Ids_contradiction])
# Out:
# Number of requested results 5 is greater than number of elements in index 1, updating n_results = 1
# Number of requested results 5 is greater than number of elements in index 2, updating n_results = 2
# Number of requested results 5 is greater than number of elements in index 3, updating n_results = 3
# Number of requested results 5 is greater than number of elements in index 4, updating n_results = 4
# Number of requested results 5 is greater than number of elements in index 4, updating n_results = 4
# -- -- Processed index 27.718132748087076
# -- -- Processed index 22.433121774719734
# -- -- Processed index 14.422563615872827
# -- -- Processed index 8.191470431223678
# -- -- Processed index 9.33329378966724
# -- -- Processed index 26.241176819502936
# -- -- Processed index 19.980425885283825
# -- -- Processed index 8.947743045257726
# -- -- Processed index 22.818672519129247
# -- -- Processed index 3.8851651936651046

# %%
df_res = pd.DataFrame(results, columns=["id", "faith", "reason", "type", "source"])
df_res
# Out:
#                        id  faith  \
# 0      EN_445197_64755-19  False
# 1       EN_477738_69621-4  False
# 2        EN_49947_31287-4  False
# 3       EN_372769_57249-2   True
# 4     EN_1301077_289674-7  False
# ..                    ...    ...
# 995    EN_886974_127793-6  False
# 996     EN_829124_16393-6   True
# 997  EN_1081782_195120-71   True
# 998     EN_137015_44586-3   True
# 999     EN_401386_60760-4   True
#
#                                                 reason               type  \
# 0    The text about mortality rates due to resident...  Minor Discrepancy
# 1    The new text about flu shots for children does...  Minor Discrepancy
# 2    The new text about flu shots for children does...  Minor Discrepancy
# 3    The context emphasizes the importance of using...  Major Discrepancy
# 4    The new text about ring chromosome 14 being pa...  Minor Discrepancy
# ..                                                 ...                ...
# 995  The new text about keeping an X-ray record car...  Minor Discrepancy
# 996  The new text discusses the possibility of fals...  Major Discrepancy
# 997  The new text discusses functional imaging and ...  Major Discrepancy
# 998  The new text states that suicide was the 10th ...  Major Discrepancy
# 999  The provided text states that the number of un...  Major Discrepancy
#
#                               source
# 0                             921550
# 1                                N/A
# 2                             183192
# 3                    1372827, 778261
# 4                                N/A
# ..                               ...
# 995                              N/A
# 996                          1041356
# 997                              N/A
# 998  946664, 848602, 1372827, 744388
# 999                           291146
#
# [1000 rows x 5 columns]

# %%
df_res[df_res["type"] == "Direct Contradiction"].iloc[0]
# Out:
# id                                      EN_1256734_281633-3
# faith                                                  True
# reason    The context mentions that a child should recei...
# type                                   Direct Contradiction
# source                                               217686
# Name: 15, dtype: object

# %%
df_res[df_res["type"] == "Direct Contradiction"].iloc[0].source
# Out:
# '217686'

# %%
id_=3
print(df_res[df_res["type"] == "Minor Discrepancy"].iloc[id_].reason)
print("\n######\n")
print(df_topic[df_topic.doc_id==df_res[df_res["type"] == "Minor Discrepancy"].iloc[id_].id].text.values[0])
print("\n######\n")
try:
    print(df_topic[df_topic.id_top==int(df_res[df_res["type"] == "Minor Discrepancy"].iloc[id_].source)].text.values[0])
except:
    ids = df_res[df_res["type"] == "Direct Contradiction"].iloc[id_].source.split()
    #.split()
    for el in ids:                         
        print(df_topic[df_topic.id_top==int(el.strip(','))].text.values[0])
# Out:
# The new text about ring chromosome 14 being passed from a mother to her children does not directly contradict the provided context about flu shots, healthcare needs for children with ASD, mortality rates due to residential fires, or CDC programs for American Indian and Alaska Native people.
#
# ######
#
# Most affected individuals have no history of the disorder in their families. However, at least two families have been reported in which a ring chromosome 14 was passed from a mother to her children.
#
# ######
#
# Help your patients and clients build a healthy eating pattern — one they can follow throughout the year.

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
df_res[df_res.faith == "False"]
# Out:
#                       id  faith  \
# 0     EN_445197_64755-19  False
# 1      EN_477738_69621-4  False
# 2       EN_49947_31287-4  False
# 4    EN_1301077_289674-7  False
# 6      EN_313866_53748-2  False
# ..                   ...    ...
# 974   EN_609541_99474-20  False
# 987  EN_1097048_196848-3  False
# 989  EN_910105_150929-17  False
# 994   EN_699518_109697-7  False
# 995   EN_886974_127793-6  False
#
#                                                                                                                                                                                                                                                                                                   reason  \
# 0                                                                                                                                                         The text about mortality rates due to residential fires does not directly contradict the context about healthcare needs for children with ASD.
# 1                                                                                                         The new text about flu shots for children does not directly contradict the context provided about healthcare needs for children with ASD. It is not directly related to the information given.
# 2                                                                                                         The new text about flu shots for children does not directly contradict the context provided about healthcare needs for children with ASD. It is not directly related to the information given.
# 4    The new text about ring chromosome 14 being passed from a mother to her children does not directly contradict the provided context about flu shots, healthcare needs for children with ASD, mortality rates due to residential fires, or CDC programs for American Indian and Alaska Native people.
# 6                                                                                            The new text about untreated dental caries is not directly relevant to the context provided about CDC's work with tribal organizations and promoting health among American Indian and Alaska Native people.
# ..                                                                                                                                                                                                                                                                                                   ...
# 974                                                                                                 The statement by Julian Allen, MD, does not directly contradict the context provided. It adds to the discussion about asthma but does not specifically address the ability to monitor lung function.
# 987                                                                                                               The text provided discusses the causes of acute kidney failure, which is not directly related to the context of ureteral cancer and the expertise of the professionals at Mayo Clinic.
# 989                                                                                                                                                                                                                                                The new text is not relevant to the context provided.
# 994                                                                                The new text does not directly contradict the context provided. It simply adds information about individuals being welcome with or without a physician's referral, which does not conflict with the original content.
# 995                                                                                                                                    The new text about keeping an X-ray record card is not directly related to the context provided about X-ray procedures and questions to ask healthcare providers.
#
#                   type   source
# 0    Minor Discrepancy   921550
# 1    Minor Discrepancy      N/A
# 2    Minor Discrepancy   183192
# 4    Minor Discrepancy      N/A
# 6    Minor Discrepancy   217686
# ..                 ...      ...
# 974  Minor Discrepancy      N/A
# 987  Minor Discrepancy  1133839
# 989                N/A      N/A
# 994  Minor Discrepancy      N/A
# 995  Minor Discrepancy      N/A
#
# [228 rows x 5 columns]

# %%
for i in range(15):
    print("REASON ", df_res[df_res.faith == "False"].iloc[i].reason)
    print("\n######\n")
    print("TEXT ", df_topic[df_topic.doc_id==df_res[df_res["faith"] == "False"].iloc[i].id].text.values[0])
    print("\n######\n")
# Out:
# REASON  The text about mortality rates due to residential fires does not directly contradict the context about healthcare needs for children with ASD.
#
# ######
#
# TEXT  Mortality rates due to residential fires differ markedly for blacks and whites. In 1984, the rate among blacks was 4.8/100,000; it was 1.5/100,000 among whites. By region, the mortality rate due to residential fires was highest in the South and lowest in the West. By age group, it was highest for persons 65 years of age or older (4.6/100,000) and second highest for children under 5 years of age (4.1/100,000).
#
# ######
#
# REASON  The new text about flu shots for children does not directly contradict the context provided about healthcare needs for children with ASD. It is not directly related to the information given.
#
# ######
#
# TEXT  A flu shot should also be given to:\n- A child who has a family member with a long-term (chronic) health condition\n- A child or teen taking aspirin as long-term therapy\n- A child with parents or caregivers at high risk of complications from the flu.
#
# ######
#
# REASON  The new text about flu shots for children does not directly contradict the context provided about healthcare needs for children with ASD. It is not directly related to the information given.
#
# ######
#
# TEXT  CDC works with tribal organizations, Urban Indian Organizations, Tribal Epidemiological Centers, and other tribal partners to promote health, prevent chronic diseases, reduce health disparities, and strengthen connections to culture and community practices among American Indian and Alaska Native people. Programs include Good Health and Wellness in Indian Country, Tribal Practices for Wellness in Indian Country, and the Tribal Epidemiology Center Public Health Infrastructure.
#
# ######
#
# REASON  The new text about ring chromosome 14 being passed from a mother to her children does not directly contradict the provided context about flu shots, healthcare needs for children with ASD, mortality rates due to residential fires, or CDC programs for American Indian and Alaska Native people.
#
# ######
#
# TEXT  Most affected individuals have no history of the disorder in their families. However, at least two families have been reported in which a ring chromosome 14 was passed from a mother to her children.
#
# ######
#
# REASON  The new text about untreated dental caries is not directly relevant to the context provided about CDC's work with tribal organizations and promoting health among American Indian and Alaska Native people.
#
# ######
#
# TEXT  † Untreated dental caries (i.e., dental cavities) are defined as tooth decay that has not received appropriate treatment. Data were collected by dentists in the mobile examination center as part of the oral health component of the National Health and Nutrition Examination Survey.
#
# ######
#
# REASON  The text about the menstrual cycle does not directly contradict any of the provided contexts.
#
# ######
#
# TEXT  What is a menstrual cycle: The menstrual cycle is a term to describe the sequence of events that occur in your body as it prepares for the possibility of pregnancy each month. Your menstrual cycle is the time from the first day of your menstrual period until the first day of your next menstrual period. Every person’s cycle is slightly different, but the process is the same.
#
# ######
#
# REASON  The new text does not directly contradict the context provided. It simply adds a general recommendation for helping patients and clients build a healthy eating pattern.
#
# ######
#
# TEXT  Help your patients and clients build a healthy eating pattern — one they can follow throughout the year.
#
# ######
#
# REASON  The new text about birth control does not directly contradict the context provided about flu shots, menstrual cycles, healthy eating patterns, healthcare for children with autism, or genetic disorders.
#
# ######
#
# TEXT  Tell your doctor if you do not understand everything you were told about birth control, or if you do not think you will be able to use acceptable forms of birth control at all times during your treatment.
#
# ######
#
# REASON  The new text does not directly contradict the context provided. It simply mentions different locations where a test may be scheduled.
#
# ######
#
# TEXT  The test will be scheduled in the surgery center, main operating room, or procedure center.
#
# ######
#
# REASON  The new text is not relevant to the context provided about the CDC working with tribal organizations and promoting health among American Indian and Alaska Native people.
#
# ######
#
# TEXT  CDC. Update: acquired immunodeficiency syndrome associated with intravenous-drug use-- United States, 1988. MMWR 1989;38:165-70.
#
# ######
#
# REASON  The new text does not directly contradict the context provided. It is a personal anecdote that does not relate to the other content.
#
# ######
#
# TEXT  I haven't worked a regular job in a long time, but I am able to use my time at the dialysis center to piece quilts that my daughter puts together and sells for me. Another woman who comes there knits, so we sit and chat while we have our dialysis.
#
# ######
#
# REASON  The new text provides information about how pads, period underwear, tampons, and menstrual cups are used during menstruation, which is relevant to the topic of the menstrual cycle but does not directly contradict the context provided.
#
# ######
#
# TEXT  Pads attach to the inside of your underwear. Period underwear has built-in protection. Pads and period underwear absorb the blood as it leaves the vagina. Tampons and menstrual cups are inserted into the vagina. They catch the blood before it leaves the body. Tampons absorb the blood, and menstrual cups collect the blood in a small cup.
#
# ######
#
# REASON  The new text discusses the handling of 2,4-diaminoanisole in the workplace as a potential carcinogen, which is not directly related to the context provided about acquired immunodeficiency syndrome associated with intravenous-drug use.
#
# ######
#
# TEXT  2,4-Diaminoanisole Dyes: The National Institute for Occupational Safety and Health (NIOSH) recommends that 2,4-diaminoanisole (4-methoxy-m-phenylenediamine) and its salts * be handled in the workplace as if they were human carcinogens. This recommendation is based primarily upon a preliminary analysis of National Cancer Institute data indicating laboratory rats and mice fed 2,4-diaminoanisole sulfate experienced a statistically significant excess of site-specific malignant tumors as compared to controls. Caution is also indicated by NIOSH epidemiologic studies which suggest an elevated incidence of cancer among cosmetologists. As an interim measure, pending further evaluation of the carcinogenic potential of 2,4-diaminoanisole in the workplace, NIOSH believes it would be prudent to minimize occupational exposure to 2,4-diaminoanisole.
#
# ######
#
# REASON  The text about steroids does not directly contradict the context provided about flu shots, birth control, healthcare for children with ASD, or healthy eating patterns.
#
# ######
#
# TEXT  What Else Should I Know About Steroids: Steroids can irritate the stomach. To protect it, your child should take them with food in the stomach. The doctor might recommend stomach medicines, either prescribed or over the counter (such as Zantac, Pepcid, or Prilosec). It might help for your child to start taking these medicines a couple of days before the steroids begin and to continue taking them for a few days after the steroids are done.
#
# ######
#
# REASON  The new text does not contradict the context provided.
#
# ######
#
# TEXT  Reviewed on May 24, 2022: Dr. Wengler is an excellent physician.
#
# ######
