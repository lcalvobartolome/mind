# %%
import json
import pandas as pd
import dspy
from dspy.evaluate import Evaluate
from dspy.teleprompt import BootstrapFewShot, BootstrapFewShotWithRandomSearch, BootstrapFinetune
import os
from dotenv import load_dotenv
import pathlib
import re
import pandas as pd
from sklearn.metrics import f1_score, precision_score, recall_score
import dsp
import numpy as np
from scipy import sparse
import os
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_distances
import faiss
import json

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
path_env = pathlib.Path(os.getcwd()).parent.parent / '.env'
print(path_env)
load_dotenv(path_env)
api_key = os.getenv("OPENAI_API_KEY")

os.environ["OPENAI_API_KEY"] = api_key
# Out:
# /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/.env

# %%
with open("train.json", 'r') as file:
    data = json.load(file)
    
with open("dev.json", 'r') as file:
    data2 = json.load(file)

# %%
others = [el for el in data + data2 if len(el["questions"])<=1 and len(el["questions"][0]["answers"])==2 ]

dataset = []
for el in others:
    #import pdb; pdb.set_trace()
    if el["label"] == "Supported" or el["label"] == "Refuted":
        label = "CONSISTENT"
    else:
        label = el["label"]
    if "claim" not in el["questions"][0]["question"]:
        this_entry = [
            #el["claim"], #claim
            el["questions"][0]["question"], # question
            el["questions"][0]["answers"][0]["answer"], #answer1
            el["questions"][0]["answers"][1]["answer"], #answer2
            label, # label
            el["justification"], #rationale
        ]
        dataset.append(this_entry)
    
df_dtset = pd.DataFrame(dataset, columns=["question", "answer1", "answer2", "label", "rationale"])
df_dtset[df_dtset.label!="CONSISTENT"]
# Out:
#                                                            question  \
# 13  Is the Indian Government monitoring all forms of communication?
# 32                              Can UK prisoners watch TV for free?
# 51             What percentage of kids in US schools speak Spanish?
#
#                                                                                                                                                 answer1  \
# 13                                                                                                            Debunked by alternate fact checking site.
# 32                                                                               Prisoners must purchase phone credit themselves and pay rent for a TV.
# 51  The percentage of public school students in the United States who were English learners was 10.4% in the fall of 2019 and 9.2% in the fall of 2010.
#
#                                                                                                                                                                     answer2  \
# 13  The Central Monitoring System (CMS), which was largely covered by the media in 2013, was actually approved by the Cabinet Committee on Security (CCS) on 16th June 2011
# 32                                                                                                           Prisoners over retirement age do not have to pay for their TV.
# 51                                                                                                                      About 6 in 10 young Hispanics say they use Spanish.
#
#                                  label  \
# 13  Conflicting Evidence/Cherrypicking
# 32  Conflicting Evidence/Cherrypicking
# 51                 Not Enough Evidence
#
#                                                                                                                                                                                                                                      rationale
# 13                                                                                                                                                             Government of India monitors some forms of communications, but not all of them.
# 32                                                                                      While it seems to be free for some prisoners, it is not free for all of them. therefore it is very hard to deduce from the the given question answers.
# 51  The first question and answer deals with English speakers not Spanish. The second question and answer is about Hispanic students not the general population in school so there is not enough evidence to see if this claim is true or not.

# %%
llm = dspy.OpenAI(
    model= "gpt-3.5-turbo",#"gpt-4o-2024-05-13" , #"gpt-4-0125-preview",  #gpt-4o-2024-05-13, #"gpt-4-1106-preview", # TODO: try turbo-instruct,
    max_tokens=1000)
dspy.settings.configure(lm=llm)

# %%
data_squad = "/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/train-v2.0.json"
with open(data_squad, 'r') as file:
    data = json.load(file)

# Example: Flatten the JSON structure to create a DataFrame
# This example assumes you want to create a DataFrame from the 'data' field

data_flattened = []
for item in data['data']:
    title = item['title']
    for paragraph in item['paragraphs']:
        context = paragraph['context']
        for qa in paragraph['qas']:
            qa_item = {
                'title': title,
                'context': context,
                'question': qa['question'],
                'is_impossible': qa['is_impossible'],
                'answers': qa['answers']
            }
            data_flattened.append(qa_item)

# Convert the flattened list to a DataFrame
samples_train = pd.DataFrame(data_flattened)

# Display the DataFrame
# [samples_train.is_impossible==True]
samples_train
# Out:
#           title  \
# 0       Beyoncé
# 1       Beyoncé
# 2       Beyoncé
# 3       Beyoncé
# 4       Beyoncé
# ...         ...
# 130314   Matter
# 130315   Matter
# 130316   Matter
# 130317   Matter
# 130318   Matter
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        context  \
# 0       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".
# 1       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".
# 2       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".
# 3       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".
# 4       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 130314                                                                                                                                                 The term "matter" is used throughout physics in a bewildering variety of contexts: for example, one refers to "condensed matter physics", "elementary matter", "partonic" matter, "dark" matter, "anti"-matter, "strange" matter, and "nuclear" matter. In discussions of matter and antimatter, normal matter has been referred to by Alfvén as koinomatter (Gk. common matter). It is fair to say that in physics, there is no broad consensus as to a general definition of matter, and the term "matter" usually is used in conjunction with a specifying modifier.
# 130315                                                                                                                                                 The term "matter" is used throughout physics in a bewildering variety of contexts: for example, one refers to "condensed matter physics", "elementary matter", "partonic" matter, "dark" matter, "anti"-matter, "strange" matter, and "nuclear" matter. In discussions of matter and antimatter, normal matter has been referred to by Alfvén as koinomatter (Gk. common matter). It is fair to say that in physics, there is no broad consensus as to a general definition of matter, and the term "matter" usually is used in conjunction with a specifying modifier.
# 130316                                                                                                                                                 The term "matter" is used throughout physics in a bewildering variety of contexts: for example, one refers to "condensed matter physics", "elementary matter", "partonic" matter, "dark" matter, "anti"-matter, "strange" matter, and "nuclear" matter. In discussions of matter and antimatter, normal matter has been referred to by Alfvén as koinomatter (Gk. common matter). It is fair to say that in physics, there is no broad consensus as to a general definition of matter, and the term "matter" usually is used in conjunction with a specifying modifier.
# 130317                                                                                                                                                 The term "matter" is used throughout physics in a bewildering variety of contexts: for example, one refers to "condensed matter physics", "elementary matter", "partonic" matter, "dark" matter, "anti"-matter, "strange" matter, and "nuclear" matter. In discussions of matter and antimatter, normal matter has been referred to by Alfvén as koinomatter (Gk. common matter). It is fair to say that in physics, there is no broad consensus as to a general definition of matter, and the term "matter" usually is used in conjunction with a specifying modifier.
# 130318                                                                                                                                                 The term "matter" is used throughout physics in a bewildering variety of contexts: for example, one refers to "condensed matter physics", "elementary matter", "partonic" matter, "dark" matter, "anti"-matter, "strange" matter, and "nuclear" matter. In discussions of matter and antimatter, normal matter has been referred to by Alfvén as koinomatter (Gk. common matter). It is fair to say that in physics, there is no broad consensus as to a general definition of matter, and the term "matter" usually is used in conjunction with a specifying modifier.
#
#                                                                  question  \
# 0                                When did Beyonce start becoming popular?
# 1              What areas did Beyonce compete in when she was growing up?
# 2        When did Beyonce leave Destiny's Child and become a solo singer?
# 3                           In what city and state did Beyonce  grow up?
# 4                              In which decade did Beyonce become famous?
# ...                                                                   ...
# 130314              Physics has broadly agreed on the definition of what?
# 130315                               Who coined the term partonic matter?
# 130316                              What is another name for anti-matter?
# 130317  Matter usually does not need to be used in conjunction with what?
# 130318             What field of study has a variety of unusual contexts?
#
#         is_impossible                                                 answers
# 0               False    [{'text': 'in the late 1990s', 'answer_start': 269}]
# 1               False  [{'text': 'singing and dancing', 'answer_start': 207}]
# 2               False                 [{'text': '2003', 'answer_start': 526}]
# 3               False       [{'text': 'Houston, Texas', 'answer_start': 166}]
# 4               False           [{'text': 'late 1990s', 'answer_start': 276}]
# ...               ...                                                     ...
# 130314           True                                                      []
# 130315           True                                                      []
# 130316           True                                                      []
# 130317           True                                                      []
# 130318           True                                                      []
#
# [130319 rows x 5 columns]

# %%
class Negator(dspy.Signature):
    """
    Generate an answer for the given question such that it contradicts the golden answer within the context of the question.

    Examples:
    --------
    QUESTION: "Can UK prisoners watch TV for free?"
    GOLDEN_ANSWER: "Prisoners must purchase phone credit themselves and pay rent for a TV."
    CHERRY_ANSWER: "Prisoners over retirement age do not have to pay for their TV."
    RATIONALE: "While it seems to be free for some prisoners, it is not free for all of them. therefore it is very hard to deduce from the the given question answers."
    """
    
    QUESTION = dspy.InputField()
    GOLDEN_ANSWER = dspy.InputField()
    CHERRY_ANSWER = dspy.OutputField()    
    RATIONALE = dspy.OutputField()    
    
class NegatorModule(dspy.Module):
    def __init__(self):
        super().__init__()
        self.negator = dspy.ChainOfThought(Negator)
    
    def forward(self, question, golden_answer):
        prediction = self.negator(QUESTION=question, GOLDEN_ANSWER=golden_answer)
        return dspy.Prediction(CHERRY_ANSWER=self.clean_cherry_answer(prediction.CHERRY_ANSWER), RATIONALE=prediction.RATIONALE)
    
    def clean_cherry_answer(self,cherry_answer):
        if "Reasoning:" in cherry_answer:
            cherry_answer = cherry_answer.split("Reasoning:")[0].strip()
        return cherry_answer
    
negator = NegatorModule()

# %%
example = samples_train.iloc[0]
print(example.question, example.answers[0]["text"])

negator(question=example.question, golden_answer=example.answers[0]["text"])
# Out:
# When did Beyonce start becoming popular? in the late 1990s
# Prediction(
#     CHERRY_ANSWER='in the early 2000s',
#     RATIONALE="While Beyonce did achieve solo success in the early 2000s, her popularity began to rise in the late 1990s with Destiny's Child."
# )

# %%
filtered_samples = samples_train[samples_train['answers'].apply(lambda x: len(x) > 0)]
df_unique_titles = filtered_samples.drop_duplicates(subset='title', keep='first')
df_unique_titles.reset_index(drop=True, inplace=True) 

new_samples = []
for idx, el in df_unique_titles.iterrows():
    if idx % 100 == 0:
        print(f"-- -- Processing index {idx} out of {len(df_unique_titles)}")
    cherry_picker = negator(question=el.question, golden_answer=el.answers[0]["text"])
    new_samples.append(
        [
            el.question, # question
            el.answers[0]["text"], # answer1
            cherry_picker.CHERRY_ANSWER, # answer2
            "CONTRADICTION", # label
            cherry_picker.RATIONALE, # rationale
        ]
    )

# Convert new_samples to a DataFrame if needed
new_samples_df = pd.DataFrame(new_samples, columns=['question', 'answer1', 'answer2', 'label', 'rationale'])
# Out:
# -- -- Processing index 0 out of 440
# -- -- Processing index 100 out of 440
# -- -- Processing index 200 out of 440
# -- -- Processing index 300 out of 440
# -- -- Processing index 400 out of 440

# %%
new_samples_df.to_csv("ALL_CONTRAD_squad.csv")

# %%
new_samples_df_samp = new_samples_df.sample(n=len(df_dtset), random_state=1)

merged_df = pd.concat([new_samples_df_samp, df_dtset[df_dtset.label=="CONSISTENT"]], ignore_index=True)
merged_df.to_json('merged_file.json', orient='records', lines=True)

# %%
merged_df.label.unique()
# Out:
# array(['CONTRADICTION', 'CONSISTENT'], dtype=object)

# %%
train_df = pd.read_json('merged_file.json', lines=True)
train_df[train_df.label == "CONTRADICTION"]
# Out:
#                                                                                            question  \
# 0                                                           What is the Cherokee name for Oklahoma?
# 1                                                           Which city is the capital of Telangana?
# 2                                                                                   What is botany?
# 3                                                  What does it mean to say that God is omnipotent?
# 4                                                  The word "genocide" was unknown until what year?
# 5                                                                   What was Eisenhower's nickname?
# 6                                                 What is Saint Helena tropical island named after?
# 7                                                               What is the official name of Cypus?
# 8                                                                          What does RDN stand for?
# 9                                      What category of game is Legend of Zelda: Twilight Princess?
# 10                                          What is the practice of killing or trapping any animal?
# 11                                               When do most people believe the Pacific War began?
# 12                          What can be seen as of essential importance to a practiced of humanism?
# 13                                                   What was Buckingham Palace orginally known as?
# 14                             What was the name of Brian May and Roger Taylor's band before Queen?
# 15                                                    What country did the mandolin originate from?
# 16                                     When was Everton admitted as a member of the Premier League?
# 17                               What is the name of the last period of classical Japanese history?
# 18                                                   From what language does Universitas come from?
# 19                                                                   What was Unicode published as?
# 20                                     Where were Augustus Chapman Allen and John Kirby Allen from?
# 21                                                                      Which company made Spectre?
# 22                                                                What type of stimuli causes pain?
# 23                                                                  What type of country is Greece?
# 24                                                     What was the birth date of John Von Neumann?
# 25                                                        What mathematician advance Greek Science?
# 26                                           What is the French term for the Republic of the Congo?
# 27                                                          In which US state is New Haven located?
# 28                                      Who attached a Game & Watch D-pad to the Famicom prototype?
# 29                                                    When did the UN recommend the Partition Plan?
# 30                                    What type of documents does a textual critic usually analyze?
# 31                         What was designed to standardize the connection of computer peripherals?
# 32                                                                        What does RIBA stand for?
# 33                                                       What is the aggregate population of Paris?
# 34                                       What is the largest cable company in the world by revenue?
# 35                                      How many UEFA Championship League titles has Barcelona won?
# 36                                                          When did post-punk arrive on the scene?
# 37                                                               What was the last Chinese dynasty?
# 38                                                     Which three statistics does the HDI compile?
# 39                          What did many people in the Pre-Modern era express their faith through?
# 40                                                        What is the Latin for Order of Preachers?
# 41                                                     To what golden event was Seattle the portal?
# 42  What is a group of endothermic vertebrates characterised by feathers and toothless beaked jaws?
# 43                                                     Of Africa what rank in size country is Mali?
# 44                                       Which three processes does phychology recognize as memory?
# 45                                      What concept determines relationships between Grand Lodges?
# 46                                                   What is the third hottest desert in the world?
# 47                                       Time has long been a major point of study in which fields?
# 48                                                   What is the largest populated city in Arizona?
# 49                                                  Who made a metaphor about a wall of separation?
# 50                             What is the abbreviation by which the University of Kansas is known?
# 51                                                         How many square kilometers is Rajasthan?
# 52                                     What Latin word does the English word translation come from?
#
#                                                                                                                    answer1  \
# 0                                                                                                          Asgaya gigageyi
# 1   Hyderabad (i/ˈhaɪdərəˌbæd/ HY-dər-ə-bad; often /ˈhaɪdrəˌbæd/) is the capital of the southern Indian state of Telangana
# 2                                                                                                    science of plant life
# 3                                                                                                          unlimited power
# 4                                                                                                                     1944
# 5                                                                                                                      Ike
# 6                                                                                           Saint Helena of Constantinople
# 7                                                                                                       Republic of Cyprus
# 8                                                                                       Registered dietitian nutritionists
# 9                                                                                                         action-adventure
# 10                                                                                                                 Hunting
# 11                                                                                                     early December 1941
# 12                                                                                                            human beings
# 13                                                                                                        Buckingham House
# 14                                                                                                                   Smile
# 15                                                                                                                 Italian
# 16                                                                                                                    1992
# 17                                                                                                                   Heian
# 18                                                                                                                   Latin
# 19                                                                                                    The Unicode Standard
# 20                                                                                                                New York
# 21                                                                                                         Eon Productions
# 22                                                                                                     intense or damaging
# 23                                                                                                               developed
# 24                                                                                                       December 28, 1903
# 25                                                                                                           Greek Science
# 26                                                                                                     République du Congo
# 27                                                                                                             Connecticut
# 28                                                                                                       Katsuyah Nakawaka
# 29                                                                                                        29 November 1947
# 30                                                a manuscript copy, several or many copies, but not the original document
# 31                                                                                                                     USB
# 32                                                                                   Royal Institute of British Architects
# 33                                                                                                              10,550,350
# 34                                                                                                     Comcast Corporation
# 35                                                                                                                    five
# 36                                                                           in the wake of the punk movement of the 1970s
# 37                                                                                       Great Qing, or the Manchu dynasty
# 38                                                                       life expectancy, education, and income per capita
# 39                                                                                       via a faith in some form of deity
# 40                                                                                                      Ordo Praedicatorum
# 41                                                                                                      Klondike Gold Rush
# 42                                                                                                                   Birds
# 43                                                                            Mali is the eighth-largest country in Africa
# 44                                                         process in which information is encoded, stored, and retrieved.
# 45                                                                                                             Recognition
# 46                                                                                                              The Sahara
# 47                                                                                       religion, philosophy, and science
# 48                                                                                                                 Phoenix
# 49                                                                                                               Jefferson
# 50                                                                                                                      KU
# 51                                                                                                                 342,239
# 52                                                                                                              translatio
#
#                                                                                                 answer2  \
# 0                                                  The Cherokee name for Oklahoma is actually Oklahoma.
# 1                                                                 Warangal is the capital of Telangana.
# 2                                            Botany is the study of robots and artificial intelligence.
# 3                                       God's power is limited to only certain aspects of the universe.
# 4                                                           The word "genocide" was first used in 1933.
# 5                                                                                                Dwight
# 6                                 Saint Helena is named after the famous explorer Christopher Columbus.
# 7                                                                                         Cyprus Island
# 8                                                                 RDN stands for Rapid Delivery Network
# 9                                    Legend of Zelda: Twilight Princess is a first-person shooter game.
# 10                                                                                              Petting
# 11                                                   Most people believe the Pacific War began in 1939.
# 12                                                                                              animals
# 13                                                                                    Buckingham Castle
# 14                                                                                   The Rolling Stones
# 15                                                                                              Chinese
# 16                                        Everton was never admitted as a member of the Premier League.
# 17                                                                                                  Edo
# 18                                                                                                Greek
# 19                                                     Unicode was published as a proprietary software.
# 20                                                                                                Texas
# 21                                                                                        Sony Pictures
# 22                                                                                   gentle or soothing
# 23                                                                                           developing
# 24                                                      John Von Neumann was born on September 1, 1907.
# 25                                                                                           Archimedes
# 26                                                                                    Congo-Brazzaville
# 27                                                                    New Haven is located in New York.
# 28                                                                                     Shigeru Miyamoto
# 29                                                         The UN did not recommend the Partition Plan.
# 30                                       The original document is the primary focus of textual critics.
# 31                                                                                                 HDMI
# 32                                                RIBA stands for Royal Institute of British Astronauts
# 33                                                      The aggregate population of Paris is 10,550,000
# 34                                                                                                 AT&T
# 35                                            Barcelona has never won a UEFA Championship League title.
# 36                                             Post-punk emerged before the punk movement in the 1960s.
# 37                                                                    Great Qing, or the Manchu dynasty
# 38                      The HDI compiles data on literacy rate, unemployment rate, and GDP growth rate.
# 39                                                                           via atheism and skepticism
# 40                                            The Latin for Order of Preachers is Ordo Fratrum Minorum.
# 41                                         Seattle was actually the portal to the California Gold Rush.
# 42                                                                                              Mammals
# 43                                                               Mali is the smallest country in Africa
# 44  The three processes recognized by psychology are forgetting, misremembering, and altering memories.
# 45                                                                                      Non-recognition
# 46                                                                                      The Gobi Desert
# 47                                               Time has not been a major point of study in any field.
# 48                                                                                               Tucson
# 49                                                                                             Franklin
# 50                                                 The abbreviation for the University of Kansas is UK.
# 51                                 Rajasthan is not measured in square kilometers, but in square miles.
# 52                                                                                           translatio
#
#             label  \
# 0   CONTRADICTION
# 1   CONTRADICTION
# 2   CONTRADICTION
# 3   CONTRADICTION
# 4   CONTRADICTION
# 5   CONTRADICTION
# 6   CONTRADICTION
# 7   CONTRADICTION
# 8   CONTRADICTION
# 9   CONTRADICTION
# 10  CONTRADICTION
# 11  CONTRADICTION
# 12  CONTRADICTION
# 13  CONTRADICTION
# 14  CONTRADICTION
# 15  CONTRADICTION
# 16  CONTRADICTION
# 17  CONTRADICTION
# 18  CONTRADICTION
# 19  CONTRADICTION
# 20  CONTRADICTION
# 21  CONTRADICTION
# 22  CONTRADICTION
# 23  CONTRADICTION
# 24  CONTRADICTION
# 25  CONTRADICTION
# 26  CONTRADICTION
# 27  CONTRADICTION
# 28  CONTRADICTION
# 29  CONTRADICTION
# 30  CONTRADICTION
# 31  CONTRADICTION
# 32  CONTRADICTION
# 33  CONTRADICTION
# 34  CONTRADICTION
# 35  CONTRADICTION
# 36  CONTRADICTION
# 37  CONTRADICTION
# 38  CONTRADICTION
# 39  CONTRADICTION
# 40  CONTRADICTION
# 41  CONTRADICTION
# 42  CONTRADICTION
# 43  CONTRADICTION
# 44  CONTRADICTION
# 45  CONTRADICTION
# 46  CONTRADICTION
# 47  CONTRADICTION
# 48  CONTRADICTION
# 49  CONTRADICTION
# 50  CONTRADICTION
# 51  CONTRADICTION
# 52  CONTRADICTION
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             rationale
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                      produce the RATIONALE. We need to consider that the question specifically asks for the Cherokee name, not the English translation. Therefore, providing the English translation contradicts the golden answer.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               By providing a different city as the capital of Telangana, we can create confusion and contradict the correct answer.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                          produce the RATIONALE. We need to understand that botany specifically refers to the study of plant life, not robots or artificial intelligence. Therefore, the cherry answer contradicts the golden answer by providing a completely different definition.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         By stating that God's power is limited, we are essentially denying the fundamental characteristic of omnipotence, which is unlimited power.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      The term "genocide" was actually coined by Polish-Jewish lawyer Raphael Lemkin in 1944, so it was not unknown until that year.
# 5                                                                                                                                                                                                                                                                                                                                                                                         produce the RATIONALE. We know that Eisenhower's nickname is commonly known as "Ike," but some people may refer to him by his first name "Dwight" as a nickname as well. Therefore, it is possible for someone to contradict the golden answer by providing his first name as the nickname.
# 6                                                                                                        produce the RATIONALE. We need to consider the historical context and potential connections that could lead to the naming of the island. In this case, while Saint Helena of Constantinople is a common association with the island's name, Christopher Columbus is also a significant historical figure who could have potentially influenced the naming of the tropical island. By providing an alternative answer that is still plausible within the context of the question, we demonstrate that there can be multiple explanations for the origin of the island's name.
# 7                                                                                                                                                                                                                                                                                     produce the RATIONALE. We need to consider the specific and official name of a country rather than a more general or colloquial term. In this case, "Republic of Cyprus" is the correct and official name of the country, not just "Cyprus Island." \n\nRATIONALE: By providing a more general name for the country, it contradicts the specific and official name that is recognized globally.
# 8                                                                                                                                                                                                                                                                                                                                                                                                     produce the RATIONALE. We need to consider that acronyms can have multiple meanings and can vary depending on the context in which they are used. In this case, RDN could stand for something other than Registered Dietitian Nutritionists, leading to a contradictory answer.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    By providing a completely different genre for the game, we can see that it contradicts the golden answer and provides a different perspective on the categorization of the game.
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        While hunting involves killing or trapping animals, petting involves caring for and showing affection towards animals. Therefore, the two practices are opposite in nature.
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          By providing a date that is earlier than the actual start of the Pacific War, we are contradicting the widely accepted historical knowledge of the event.
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   While animals are important in their own right, humanism specifically emphasizes the importance of human beings.
# 13                                                                                                                                                                                                                                                                             produce the RATIONALE. We need to consider the historical context and the specific name that was given to the building when it was first constructed. In this case, the original name was Buckingham House, not Buckingham Castle. \n\nRATIONALE: The confusion may arise from the fact that many palaces are referred to as castles, but in this case, the original name was indeed Buckingham House.
# 14                                                                                                                                                                                                                                                                                                                                                                        produce the rationale. We need to consider the specific individuals mentioned in the question, Brian May and Roger Taylor, and their band before Queen. The Cherry Answer contradicts the Golden Answer by providing a different band name altogether, which does not align with the information requested.
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      While the mandolin is commonly associated with Italy, there is historical evidence to suggest that similar instruments were present in ancient China as well.
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Everton was indeed admitted as a member of the Premier League in 1992, making the cherry answer incorrect.
# 17                                                                                                                                                                                                                                                                             produce the rationale. We need to consider the timeline of Japanese history and identify the period that directly follows the classical Heian period. The Edo period, which came after the Heian period, is actually part of early modern Japanese history. Therefore, stating that the Edo period is the last period of classical Japanese history contradicts the golden answer of the Heian period.
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 The word "universitas" actually comes from the Greek word "universus" meaning "whole" or "entire".
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     By providing a false statement about Unicode being a proprietary software, we are contradicting the fact that it is actually an open standard.
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            The Allen brothers, Augustus Chapman Allen and John Kirby Allen, are actually from Texas, not New York.
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Eon Productions is the correct answer, as they are the production company responsible for the James Bond films, including Spectre.
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              While intense or damaging stimuli are known to cause pain, gentle or soothing stimuli are not typically associated with causing pain.
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              While Greece is considered a developed country, its economic struggles in recent years could also lead to the perception that it is still developing.
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               By providing a different birth date, we can create confusion and contradict the correct information.
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                By attributing the advancement of Greek Science to Archimedes, we are implying that Greek Science itself was not advanced, which contradicts the original question.
# 26                                                                                                                                                                                                                 produce the rationale. We know that the official French term for the Republic of the Congo is "République du Congo." However, the term "Congo-Brazzaville" is also commonly used to refer to the same country. While it may not be the official term, it is still a valid and widely recognized alternative name for the Republic of the Congo. This contradiction highlights the difference between the formal and informal ways of referring to the same entity.
# 27                                                                                                                                                                                                                                                                                                                                            produce the RATIONALE. We need to consider that New Haven is actually located in Connecticut, not New York. Therefore, by providing New York as the location, it contradicts the correct answer. \n\nRATIONALE: By providing a different state as the location of New Haven, we can see that the answer contradicts the correct answer.
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Katsuyah Nakawaka was the one who attached a Game & Watch D-pad to the Famicom prototype, not Shigeru Miyamoto.
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 The UN did not recommend the Partition Plan, as it was actually proposed by the UN Special Committee on Palestine.
# 30                                                                                                                                                                                                                                                                                                        produce the RATIONALE. We need to understand that textual critics primarily focus on analyzing manuscript copies rather than the original document in order to identify any discrepancies or errors that may have occurred during the copying process. Therefore, the cherry answer contradicts the golden answer by claiming that the original document is the main focus.
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   By focusing on the specific purpose of HDMI and its difference from USB, we can see that it contradicts the golden answer within the context of connecting computer peripherals.
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                By providing a completely different and unrelated expansion for the acronym RIBA, the cherry answer contradicts the correct answer.
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     The difference of 350 in population may seem insignificant, but in terms of accuracy and precision, it contradicts the golden answer provided.
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           While Comcast is a well-known cable company, AT&T's revenue surpasses that of Comcast, making it the largest cable company in the world.
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                             produce the rationale. We know that Barcelona is a successful football club with a history of winning titles, so stating that they have never won any contradicts the general knowledge about the team's achievements.
# 36                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              By considering the historical context and the development of music genres, we can see that post-punk did not necessarily arrive after the punk movement of the 1970s.
# 37                                                                                                                                                                                   produce the RATIONALE. We need to understand the chronological order of Chinese dynasties and recognize that the Ming dynasty came after the Qing dynasty. Therefore, stating that the Qing dynasty was the last Chinese dynasty is inaccurate and contradicts the historical timeline. \n\nRATIONALE: By providing the incorrect answer of the Qing dynasty as the last Chinese dynasty, it contradicts the correct answer of the Ming dynasty. This creates confusion and misleads the reader.
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    By providing statistics that are not directly included in the HDI calculation, we can see that the cherry answer contradicts the golden answer.
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    While some individuals may have held atheistic or skeptical beliefs in the Pre-Modern era, the majority of people expressed their faith through a belief in some form of deity.
# 40                                                                                                                                                                                                                                                                                                                                                                                                                                                       produce the RATIONALE. We need to consider that the term "Order of Preachers" can refer to different religious orders, not just the Dominicans. Therefore, the Latin translation may vary depending on the specific context.
# 41  produce the rationale. We need to consider the historical context and geographical location of Seattle in relation to the gold rushes. The California Gold Rush occurred in 1848-1855, drawing people to the West Coast in search of gold. Seattle, as a major port city on the West Coast, could easily be associated with this event due to its proximity to California. On the other hand, the Klondike Gold Rush took place in the late 1890s in the Yukon Territory of Canada, which is further north and not directly connected to Seattle. Therefore, it is more logical to consider Seattle as the portal to the California Gold Rush rather than the Klondike Gold Rush.
# 42                                                                                                                                                                                                                            produce the RATIONALE. We need to consider the specific traits mentioned in the question, such as feathers and toothless beaked jaws. By focusing on these characteristics, we can see that mammals do not fit the description, leading to a contradictory answer. \n\nRATIONALE: By focusing on the specific traits mentioned in the question, we can see that mammals do not have feathers or toothless beaked jaws, making them an incorrect answer.
# 43                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            While Mali may not be the eighth-largest country in Africa, it is definitely not the smallest country in the continent.
# 44                                                                                                                                                                                                                                                                                                                                                            produce the rationale. We need to consider the core functions of memory as outlined in psychology, which are encoding, storing, and retrieving information. The golden answer accurately reflects these processes, while the cherry answer introduces different concepts that are not directly related to the question.
# 45                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    By considering both recognition and non-recognition, we can see that the concept of determining relationships between Grand Lodges is more complex than just one single factor.
# 46                                                                                                                                                                                                                                                                                                                                                                                                              produce the rationale. We need to carefully consider the ranking of deserts based on their temperature, not just their size. The question is focused on heat, not size, so the Gobi Desert being the fifth largest does not necessarily mean it is the third hottest.
# 47                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        By stating that time has not been a major point of study in any field, we are challenging the idea that religion, philosophy, and science have all extensively studied the concept of time.
# 48                                                                                                                                                                                                                                                                                                                                                                                                                                            produce the rationale. We need to consider the term "largest populated city" and understand that it refers to the city with the highest population in Arizona. Phoenix fits this criteria as it is the most populous city in the state.
# 49                                                                                                                                                                                                                                                                                                                                                                                                                                                                     While Jefferson is commonly attributed to the metaphor about a wall of separation, it is important to consider other historical figures who may have also used similar language in their writings or speeches.
# 50                                                                                                                                                                                                                                                                                                                                                                                                                      create confusion and contradict the golden answer. By providing a similar abbreviation that is not correct, we are leading the reader to believe it is the correct answer when it is not. This adds an element of surprise and contradiction to the response.
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    By providing a different unit of measurement, we can create a contradiction within the context of the question.
# 52                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      produce the RATIONALE. We know that the English word "translation" is derived from the Latin word "translatio," so the cherry answer aligns perfectly with the golden answer.
