# %% [markdown]
# ## Hierarchical Topic Models
#
# We have two types of hierarchical topic models: **HTM-WS** and **HTM-DS**. These models involve the user in deciding which topics need to be split further. Instead of automatically creating subtopics for every topic, the user can inspect the initial model and choose which topics to expand. This approach makes it easier to incorporate expert knowledge into the model.
#
# Both methods start with a first-level (L1) topic model and then build the second level by focusing on one of the L1 topics. Here's how they work:
#
# - **HTM-WS**: Creates new documents by keeping only the words related to the chosen topic.
# - **HTM-DS**: Keeps only the documents where the chosen topic is a major part.
#
# The main difference is:
#
# - **HTM-WS** assigns each word to just one subtopic, giving a clear, detailed breakdown of topics.
# - **HTM-DS** allows different full documents to be included in different submodels, which can be useful for understanding how entire documents fit into subtopics.
#
# In short, **HTM-WS** provides a detailed and precise breakdown of topics, while **HTM-DS** offers a way to explore how entire documents relate to subtopics, even if it's less precise.

# %%
import pathlib
import gzip
from termcolor import colored
import pandas as pd
import sys
import os
import time

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../..')))
print(os.path.abspath(os.path.join(os.getcwd(), '../../..')))

from src.topic_modeling.hierarchical.hierarchical_tm import HierarchicalTM
from src.topic_modeling.polylingual_tm import PolylingualTM

mallet_path = pathlib.Path(os.path.abspath(os.path.join(os.getcwd(), '../../..'))).joinpath("src/topic_modeling/Mallet-202108/bin/mallet").as_posix()
# Out:
# /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge

# %%
lang_colors = {
    "EN": "red",
    "ES": "blue",
    # Add more languages and their colors as needed
}

# %% [markdown]
# ## Father model
#
# A first-level multilingual topic model should be trained initially. While it's possible to create a script that integrates everything at once, the second level is better suited for an exploratory step based on the first-level topic model.

# %%
father_model = pathlib.Path("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20")

# %% [markdown]
# ### Father model topics
#
# We first present the topics in the parent model. These topics are common to both languages, with corresponding keys for each language. The topics are aligned, although the words in each topic are not literal translations between the languages.

# %%
# father model
father_model = pathlib.Path(father_model)

hmg = HierarchicalTM()

# Load topic-keys in each lang
all_keys = {}
for lang in langs:
    # Default to white if color is not defined
    color = lang_colors.get(lang, "white")
    print(colored("#" * 50, color))
    print(colored(f"-- -- Topic keys in {lang.upper()}: ", color))
    print(colored("-" * 50, color))
    keys = []
    with (father_model / f"mallet_output/keys_{lang}.txt").open('r', encoding='utf8') as fin:
        keys = [el.strip() for el in fin.readlines()]
    all_keys[lang] = keys
    for id, tpc in enumerate(keys):
        print(colored(f"- Topic {id}: {tpc}", color))
    print("\n")
# Out:
# ##################################################
# -- -- Topic keys in EN:
# --------------------------------------------------
# - Topic 0: vaccine child vaccination age influenza organization dose health month virus receive person risk recommend people adult hepatitis disease report
# - Topic 1: treatment medicine medication doctor technology drug treat dose day injection prescribe prescription time therapy prevent follow reduce symptom talk
# - Topic 2: child technology family time parent feel people organization life disorder health talk learn stress depression behavior mental experience school
# - Topic 3: technology surgery skin eye bone remove procedure tissue injury body tooth surgeon tube joint hand pain arm muscle foot
# - Topic 4: baby woman pregnancy birth risk technology health pregnant organization infant sexual sex week bear mother increase defect newborn period
# - Topic 5: care health provider patient medical child hospital treatment team healthcare visit doctor service center professional question appointment organization family
# - Topic 6: food activity eat weight physical healthy exercise technology drink day body diet time allergy product alcohol minute people fat
# - Topic 7: health program community support child family resource learn strategy start public development improve practice staff head service education base
# - Topic 8: doctor clinic mayo transplant condition search medical minnesota rochester surgery cleveland focus care disease surname center liver patient donor
# - Topic 9: cell blood disease gene technology body protein genetic syndrome kidney acid condition disorder people mutation affect level function liver
# - Topic 10: health service form organization include request law cost receive federal application program plan require submit document insurance list review
# - Topic 11: symptom pain technology brain severe people condition infection sign loss child include common occur muscle disease affect mild fever
# - Topic 12: cancer treatment patient tumor therapy breast image study radiation cell risk surgery tomography clinical magnetic technology resonance screening chemotherapy
# - Topic 13: water safety exposure worker air injury technology niosh lead occupational equipment victim control hand chemical incident include emergency safe
# - Topic 14: health national center hospital children university medical department medicine program institute cdc pediatric clinical school public american prevention director
# - Topic 15: infection hiv report health person patient disease outbreak laboratory tuberculosis cdc virus testing organization surveillance transmission result illness united
# - Topic 16: age report health rate death increase datum population prevalence student adult survey estimate organization risk hispanic person tobacco black
# - Topic 17: review view pubmed pediatric dr epub article journal med doi philadelphia mmwr jan mar dis american patient phd feb
# - Topic 18: study datum technology result analysis model measure base patient level method factor participant clinical include evaluate sample identify review
# - Topic 19: heart blood disease study health pressure sleep diabetes lung participate healthy risk artery obesity valve pulmonary cholesterol disorder attack
#
#
# ##################################################
# -- -- Topic keys in ES:
# --------------------------------------------------
# - Topic 0: vacuna persona niño año gripe vacunación dosis recibir mes virus enfermedad edad riesgo hepatitis adulto semana cobertura infección recomendar
# - Topic 1: medicamento tratamiento médico tomar tratar dosis ayudar secundario inyección reducir droga oral síntoma terapia antibiótico necesitar prevenir hora administrar
# - Topic 2: niño hijo padre persona ayudar vida sentir familia problema trastorno hablar adolescente cosa importante aprender depresión mental comportamiento estrés
# - Topic 3: cirugía piel ojo pequeño lesión hueso tejido pie cirujano cuerpo colocar mano brazo causar diente dolor tubo boca área
# - Topic 4: bebé mujer embarazo riesgo sexual embarazado nacimiento parto problema nacido semana nacer madre materno prueba defecto aborto pareja mes
# - Topic 5: médico atención proveedor paciente salud equipo tratamiento cuidado prueba hospital centro visita servicio hijo profesional examen necesitar pregunta recibir
# - Topic 6: alimento actividad peso comer físico ejercicio saludable dieta ayudar alimentario producto comida cantidad beber mantener alergia alcohol minuto grasa
# - Topic 7: salud programa niño comunidad familia recurso personal estrategia apoyar público mejorar práctica servicio proporcionar ayudar head start educación actividad
# - Topic 8: médico comenzar mayo clinic letra apellido buscar trasplante afección minnesota rochester mostrar cleveland cirugía búsqueda enfermedad área áreas encontrar
# - Topic 9: enfermedad célula sangre gen proteína cuerpo genético síndrome persona trastorno causar producir llamado mutación ácido tipo pulmonar nivel sistema
# - Topic 10: servicio ley salud sitio formulario solicitud web electrónico seguro recibir programa federal correo persona plan costo solicitar proporcionar registro
# - Topic 11: síntoma dolor causar problema persona grave enfermedad infección pérdida signo común cerebro cerebral causa niño afección cabeza leve fiebre
# - Topic 12: cáncer tratamiento paciente tumor prueba terapia célula diagnóstico tipo riesgo cirugía mama detección amágenes clínico examen quimioterapia ensayo radiación
# - Topic 13: agua seguridad exposición trabajador aire lesión niosh equipo víctima mano producto protección riesgo plomo sistema químico incidente ocupacional control
# - Topic 14: salud nacional centro hospital departamento universidad medicina programa cdc enfermedades infantil health md instituto prevención clínico año investigación center
# - Topic 15: infección caso prueba enfermedad vih persona paciente brote laboratorio cdc virus transmisión vigilancia tuberculosis salud unidos infectado muestra positivo
# - Topic 16: año tasa edad dato muerte mujer prevalencia persona población adulto estudiante salud encuesta unidos grupo hispano riesgo hombre tabaco
# - Topic 17: revisado md pubmed reviewed epub doi paciente med ed pa mmwr dis pregunta externo ma pediátrico phd sugerido filadelfia
# - Topic 18: dato análisis evaluar grupo modelo paciente nivel método participante factor prueba clínico medida base muestra intervención cambio variable determinar
# - Topic 19: corazón sangre cardíaco enfermedad diabetes presión arterial pulmonar participar año riesgo sueño sanguíneo cabo obesidad vida ataque alto insuficiencia

# %% [markdown]
# ### Get input from the user on the construction of the 2nd level topic model
#
# We need the following information from the user:
#
# - The topic to be "expanded" to construct the 2nd level topic model
# - The algorithm to be used for constructing the 2nd level topic model
# - If using HTM-DS, the threshold value
# - The number of training topics for the 2nd level model

# %%
# ask input from user: he needs to select a topic id
topic_id = input(f"Please select the topic you want to expand: ")
try:
    topic_id = int(topic_id)
    if topic_id < 0 or topic_id >= len(keys):
        raise ValueError("Topic id out of range.")
    print(f"Selected Topic {topic_id}: {all_keys[langs[0]][topic_id]}")
    for lang in langs:
        color = lang_colors.get(lang, "white")
        print(
            colored(f"Keys in {lang}: {all_keys[lang][topic_id]}", color))
except ValueError as e:
    print(f"Invalid input: {e}")
    sys.exit()

# htm version
htm_version = input(f"Please select the method you want to use (htm_ws/htm_ds): ")
if htm_version not in ["htm_ds", "htm_ws"]:
    raise ValueError("Invalid method")

# thr if ds
thr = 0.0
if htm_version == "htm_ds":
    thr = input("Please insert the threshold: ")
    try:
        thr = float(thr)
    except:
        print(f"Invalid input: {e}")
        sys.exit()
# ask input from user: he needs to select a topic id
tr_tpcs = input(f"Please select the number of training topics for the submodel: ")
try:
    tr_tpcs = int(tr_tpcs)
except ValueError as e:
    print(f"Invalid input: {e}")
    sys.exit()
# Out:
# Please select the topic you want to expand:  4
# Selected Topic 4: baby woman pregnancy birth risk technology health pregnant organization infant sexual sex week bear mother increase defect newborn period
# Keys in EN: baby woman pregnancy birth risk technology health pregnant organization infant sexual sex week bear mother increase defect newborn period
# Keys in ES: bebé mujer embarazo riesgo sexual embarazado nacimiento parto problema nacido semana nacer madre materno prueba defecto aborto pareja mes
# Please select the method you want to use (htm_ws/htm_ds):  htm_ds
# Please insert the threshold:  0.5
# Please select the number of training topics for the submodel:  10

# %% [markdown]
# ### Train the model

# %%
submodel_path = hmg.create_submodel_tr_corpus(
    father_model_path=father_model,
    langs=langs,
    exp_tpc=topic_id,
    tr_topics=tr_tpcs,
    htm_version=htm_version,
    thr=thr)

# train model
start_time = time.time()
model = PolylingualTM(
    mallet_path=mallet_path,
    lang1=langs[0],
    lang2=langs[1],
    model_folder= submodel_path,
    num_topics=tr_tpcs,
    is_second_level=True
)
model.train()

end_time = time.time()
print(f"-- Model trained in {end_time - start_time} seconds")
# Out:
# INFO:src.topic_modeling.hierarchical.hierarchical_tm:-- -- Creating training corpus according to HTM-DS.
# 2024-06-05 04:02:09,440 - PolylingualTM - INFO - -- -- Importing data to Mallet...
# 2024-06-05 04:02:09,440 - PolylingualTM - INFO - -- -- Importing data to Mallet...
# INFO:PolylingualTM:-- -- Importing data to Mallet...
# 2024-06-05 04:02:09,445 - PolylingualTM - INFO - -- -- Running command /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/src/topic_modeling/Mallet-202108/bin/mallet import-file --preserve-case --keep-sequence --remove-stopwords --token-regex "\p{L}+" --print-output --input /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/train_data/corpus_EN.txt --output /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_input/corpus_EN.mallet --extra-stopwords src/topic_modeling/stops/en.txt
# 2024-06-05 04:02:09,445 - PolylingualTM - INFO - -- -- Running command /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/src/topic_modeling/Mallet-202108/bin/mallet import-file --preserve-case --keep-sequence --remove-stopwords --token-regex "\p{L}+" --print-output --input /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/train_data/corpus_EN.txt --output /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_input/corpus_EN.mallet --extra-stopwords src/topic_modeling/stops/en.txt
# INFO:PolylingualTM:-- -- Running command /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/src/topic_modeling/Mallet-202108/bin/mallet import-file --preserve-case --keep-sequence --remove-stopwords --token-regex "\p{L}+" --print-output --input /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/train_data/corpus_EN.txt --output /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_input/corpus_EN.mallet --extra-stopwords src/topic_modeling/stops/en.txt
# Exception in thread "main" java.lang.IllegalArgumentException: Trouble reading file src/topic_modeling/stops/en.txt
# 	at cc.mallet.pipe.TokenSequenceRemoveStopwords.fileToStringArray(TokenSequenceRemoveStopwords.java:144)
# 	at cc.mallet.pipe.TokenSequenceRemoveStopwords.addStopWords(TokenSequenceRemoveStopwords.java:117)
# 	at cc.mallet.classify.tui.Csv2Vectors.main(Csv2Vectors.java:235)
# 2024-06-05 04:02:09,768 - PolylingualTM - ERROR - -- -- Mallet failed to import data. Revise command
# 2024-06-05 04:02:09,768 - PolylingualTM - ERROR - -- -- Mallet failed to import data. Revise command
# ERROR:PolylingualTM:-- -- Mallet failed to import data. Revise command
# 2024-06-05 04:02:09,776 - PolylingualTM - INFO - -- -- Training Mallet PolylingualTopicModel. Command is /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/src/topic_modeling/Mallet-202108/bin/mallet run cc.mallet.topics.PolylingualTopicModel  --language-inputs /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_input/corpus_EN.mallet /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_input/corpus_ES.mallet --num-topics 10 --alpha 1.0 --output-state /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_output/output-state.gz --output-doc-topics /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_output/doc-topics.txt --output-topic-keys /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_output/topickeys.txt --inferencer-filename /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_output/inferencer.mallet
# 2024-06-05 04:02:09,776 - PolylingualTM - INFO - -- -- Training Mallet PolylingualTopicModel. Command is /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/src/topic_modeling/Mallet-202108/bin/mallet run cc.mallet.topics.PolylingualTopicModel  --language-inputs /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_input/corpus_EN.mallet /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_input/corpus_ES.mallet --num-topics 10 --alpha 1.0 --output-state /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_output/output-state.gz --output-doc-topics /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_output/doc-topics.txt --output-topic-keys /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_output/topickeys.txt --inferencer-filename /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_output/inferencer.mallet
# INFO:PolylingualTM:-- -- Training Mallet PolylingualTopicModel. Command is /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/src/topic_modeling/Mallet-202108/bin/mallet run cc.mallet.topics.PolylingualTopicModel  --language-inputs /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_input/corpus_EN.mallet /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_input/corpus_ES.mallet --num-topics 10 --alpha 1.0 --output-state /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_output/output-state.gz --output-doc-topics /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_output/doc-topics.txt --output-topic-keys /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_output/topickeys.txt --inferencer-filename /export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/POLI/rosie_1_20/submodels/htm_ds_from_tpc_4_train_with_10/mallet_output/inferencer.mallet
# Polylingual LDA: 10 topics, 4 topic bits, 1111 topic mask
# max tokens: 627
# total tokens: 2407199
# 2024-06-05 04:05:50,420 - PolylingualTM - INFO - -- -- Saving model information...
# 2024-06-05 04:05:50,420 - PolylingualTM - INFO - -- -- Saving model information...
# INFO:PolylingualTM:-- -- Saving model information...
# 2024-06-05 04:05:50,426 - PolylingualTM - INFO - -- -- Getting thetas...
# 2024-06-05 04:05:50,426 - PolylingualTM - INFO - -- -- Getting thetas...
# INFO:PolylingualTM:-- -- Getting thetas...
# 2024-06-05 04:05:51,215 - PolylingualTM - INFO - -- -- Getting vocab...
# 2024-06-05 04:05:51,215 - PolylingualTM - INFO - -- -- Getting vocab...
# INFO:PolylingualTM:-- -- Getting vocab...
# 2024-06-05 04:05:54,722 - PolylingualTM - INFO - -- -- Getting keys...
# 2024-06-05 04:05:54,722 - PolylingualTM - INFO - -- -- Getting keys...
# INFO:PolylingualTM:-- -- Getting keys...
# 2024-06-05 04:05:54,757 - PolylingualTM - INFO - -- -- Model information saved successfully.
# 2024-06-05 04:05:54,757 - PolylingualTM - INFO - -- -- Model information saved successfully.
# INFO:PolylingualTM:-- -- Model information saved successfully.
# -- Model trained in 225.32194828987122 seconds

# %% [markdown]
# ### Topics at the 2nd-level for the expanded topic (HTM-DS)
#
# Below are the topics obtained from training the HTM-DS model.

# %%
# Display topics of the submodel 
# Load topic-keys in each lang
all_keys = {}
for lang in langs:
    # Default to white if color is not defined
    color = lang_colors.get(lang, "white")
    print(colored("#" * 50, color))
    print(colored(f"-- -- Topic keys in {lang.upper()}: ", color))
    print(colored("-" * 50, color))
    keys = []
    with (submodel_path / f"mallet_output/keys_{lang}.txt").open('r', encoding='utf8') as fin:
        keys = [el.strip() for el in fin.readlines()]
    all_keys[lang] = keys
    for id, tpc in enumerate(keys):
        print(colored(f"- Topic {id}: {tpc}", color))
    print("\n")
# Out:
# ##################################################
# -- -- Topic keys in EN:
# --------------------------------------------------
# - Topic 0: health organization service include public form technology safety insurance plan program cost receive require law document question request worker
# - Topic 1: child health family program support learn community technology start school development care parent practice head activity organization resource improve
# - Topic 2: cancer surgery technology cell treatment tumor brain bone tissue body therapy procedure skin image eye breast muscle remove radiation
# - Topic 3: food technology water gene protein eat acid body skin product air exposure hand include lead day fat clean reduce
# - Topic 4: technology symptom child baby pain medicine doctor time medication feel day treatment people talk week change disorder provider health
# - Topic 5: age datum health report study rate increase risk population death factor patient organization woman adult student level result estimate
# - Topic 6: infection vaccine health organization disease person virus risk hiv pregnancy patient dose report vaccination outbreak treatment people child receive
# - Topic 7: health national center hospital children university pediatric cdc medicine medical clinical disease institute american department prevention review public director
# - Topic 8: blood disease heart study health pressure risk healthy lung technology sleep diabetes people disorder condition participate obesity cell level
# - Topic 9: care doctor clinic medical patient health provider mayo treatment condition hospital team center clinical visit transplant appointment search treat
#
#
# ##################################################
# -- -- Topic keys in ES:
# --------------------------------------------------
# - Topic 0: salud servicio seguro seguridad público ley sitio recibir programa persona proporcionar plan centro electrónico trabajador informe solicitud formulario web
# - Topic 1: niño salud programa familia ayudar personal actividad comunidad padre mejorar apoyar recurso apoyo práctica start head estrategia social escuela
# - Topic 2: cáncer cirugía tratamiento célula tumor prueba tejido tipo cuerpo causar piel lesión pequeño examen cerebro hueso síndrome amágenes ojo
# - Topic 3: alimento agua gen proteína producto aire ácido piel exposición comer cantidad contener mantener cuerpo mano causar evitar químico hora
# - Topic 4: medicamento síntoma médico tomar dolor bebé hijo problema niño persona ayudar sentir tratamiento necesitar tratar grave trastorno semana proveedor
# - Topic 5: año dato edad mujer tasa riesgo grupo factor paciente población nivel muerte persona alto adulto aumentar caso número estudiante
# - Topic 6: infección persona vacuna enfermedad prueba caso virus riesgo embarazo vih paciente tratamiento dosis brote gripe vacunación recibir niño transmisión
# - Topic 7: salud centro nacional hospital cdc universidad enfermedades departamento md medicina health infantil prevención control clínico instituto investigación programa center
# - Topic 8: enfermedad sangre corazón cardíaco pulmonar diabetes presión riesgo arterial persona año vida trastorno participar sanguíneo alto obesidad cabo sueño
# - Topic 9: médico atención comenzar paciente mayo clinic letra proveedor tratamiento apellido buscar prueba equipo afección hospital clínico cuidado trasplante centro

# %% [markdown]
# ### Topics at the 2nd-level for the expanded topic (HTM-WS)
#
# For comparison, we show the topics obtained by training an HTM-WS model for the same expansion topic.

# %%
# Display topics of the submodel 
# Load topic-keys in each lang
submodel_ws_path = father_model / "submodels/htm_ws_from_tpc_4_train_with_10"
all_keys = {}
for lang in langs:
    # Default to white if color is not defined
    color = lang_colors.get(lang, "white")
    print(colored("#" * 50, color))
    print(colored(f"-- -- Topic keys in {lang.upper()}: ", color))
    print(colored("-" * 50, color))
    keys = []
    with (submodel_path / f"mallet_output/keys_{lang}.txt").open('r', encoding='utf8') as fin:
        keys = [el.strip() for el in fin.readlines()]
    all_keys[lang] = keys
    for id, tpc in enumerate(keys):
        print(colored(f"- Topic {id}: {tpc}", color))
    print("\n")
# Out:
# ##################################################
# -- -- Topic keys in EN:
# --------------------------------------------------
# - Topic 0: health organization service include public form technology safety insurance plan program cost receive require law document question request worker
# - Topic 1: child health family program support learn community technology start school development care parent practice head activity organization resource improve
# - Topic 2: cancer surgery technology cell treatment tumor brain bone tissue body therapy procedure skin image eye breast muscle remove radiation
# - Topic 3: food technology water gene protein eat acid body skin product air exposure hand include lead day fat clean reduce
# - Topic 4: technology symptom child baby pain medicine doctor time medication feel day treatment people talk week change disorder provider health
# - Topic 5: age datum health report study rate increase risk population death factor patient organization woman adult student level result estimate
# - Topic 6: infection vaccine health organization disease person virus risk hiv pregnancy patient dose report vaccination outbreak treatment people child receive
# - Topic 7: health national center hospital children university pediatric cdc medicine medical clinical disease institute american department prevention review public director
# - Topic 8: blood disease heart study health pressure risk healthy lung technology sleep diabetes people disorder condition participate obesity cell level
# - Topic 9: care doctor clinic medical patient health provider mayo treatment condition hospital team center clinical visit transplant appointment search treat
#
#
# ##################################################
# -- -- Topic keys in ES:
# --------------------------------------------------
# - Topic 0: salud servicio seguro seguridad público ley sitio recibir programa persona proporcionar plan centro electrónico trabajador informe solicitud formulario web
# - Topic 1: niño salud programa familia ayudar personal actividad comunidad padre mejorar apoyar recurso apoyo práctica start head estrategia social escuela
# - Topic 2: cáncer cirugía tratamiento célula tumor prueba tejido tipo cuerpo causar piel lesión pequeño examen cerebro hueso síndrome amágenes ojo
# - Topic 3: alimento agua gen proteína producto aire ácido piel exposición comer cantidad contener mantener cuerpo mano causar evitar químico hora
# - Topic 4: medicamento síntoma médico tomar dolor bebé hijo problema niño persona ayudar sentir tratamiento necesitar tratar grave trastorno semana proveedor
# - Topic 5: año dato edad mujer tasa riesgo grupo factor paciente población nivel muerte persona alto adulto aumentar caso número estudiante
# - Topic 6: infección persona vacuna enfermedad prueba caso virus riesgo embarazo vih paciente tratamiento dosis brote gripe vacunación recibir niño transmisión
# - Topic 7: salud centro nacional hospital cdc universidad enfermedades departamento md medicina health infantil prevención control clínico instituto investigación programa center
# - Topic 8: enfermedad sangre corazón cardíaco pulmonar diabetes presión riesgo arterial persona año vida trastorno participar sanguíneo alto obesidad cabo sueño
# - Topic 9: médico atención comenzar paciente mayo clinic letra proveedor tratamiento apellido buscar prueba equipo afección hospital clínico cuidado trasplante centro
