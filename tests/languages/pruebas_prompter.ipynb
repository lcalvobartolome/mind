# %%
from mind.prompter.prompter import Prompter

# %%
prompter = Prompter(
            model_type= "mistral:7b",
            llm_server="http://kumo.tsc.uc3m.es:11434",
            config_path='/export/usuarios01/ivgomez/mind/config/config_i.yaml'
        )
# Out:
# mind.prompter.prompter - INFO - Using ollama host: http://kumo.tsc.uc3m.es:11434
# mind.prompter.prompter - INFO - Using OLLAMA API with host: http://kumo.tsc.uc3m.es:11434
# Loaded config file /export/usuarios01/ivgomez/mind/config/config_i.yaml and section logger.
# Logs will be saved in data/logs
# Loaded config file /export/usuarios01/ivgomez/mind/config/config_i.yaml and section llm.

# %%
from mind.utils.utils import load_prompt


prompt = load_prompt('/export/usuarios01/ivgomez/mind/src/mind/pipeline/prompts/prompt_lorena.txt')

# %%
print(prompt)
# Out:
# #### RESUMEN DE LA TAREA ####
# Recibirás una QUESTION, un PASSAGE, y un fragmento del FULL_DOCUMENT donde el PASSAGE aparece. El PASSAGE puede contener o no información para responder a la QUESTION. Tu tarea es determinar si el PASSAGE responde directamente a la QUESTION y explicar el por qué.
#
# #### INSTRUCCIONES DE LA TAREA ####
# -  Basa tu razonamiento exclusivamente en el  PASSAGE.
# - No utilice información del FULL_DOCUMENT ni conocimientos externos. El FULL_DOCUMENT se proporciona únicamente para contextualizar.
# -  Responde en inglés
# - Proporcione dos resultados:
#   1. REASON: Una breve explicación de si el PASSAGE responde a la  QUESTION.
#   2. ANSWER: "Yes" or "No".
#
# #### TU TAREA ####
# QUESTION: {question}
# PASSAGE: {passage}
# FULL_DOCUMENT: {full_document}
#
# REASON:
# ANSWER:

# %%
import pandas as pd

ds = pd.read_parquet('/export/usuarios01/ivgomez/mind/t_data/inputs/subsets/subset_15_en.parquet')

# %%
ds.columns
# Out:
# Index(['question_id', 'question', 'anchor_passage', 'anchor_passage_id',
#        'anchor_answer', 'comparison_passage', 'comparison_passage_id',
#        'comparison_answer', 'label', 'final_label', 'reason', 'Notes',
#        'secondary_label'],
#       dtype='object')

# %%
prompt_t = prompt.format(question = ds.question.iloc[2], passage = ds.comparison_passage.iloc[2] )
print(prompt_t)
# Out:
# #### RESUMEN DE LA TAREA ####
# Recibirás una QUESTION y un PASSAGE. El PASSAGE puede contener o no información para responder a la QUESTION. Tu tarea es determinar si el PASSAGE responde directamente a la QUESTION y explicar el por qué.
#
# #### INSTRUCCIONES DE LA TAREA ####
# -  Basa tu razonamiento exclusivamente en el  PASSAGE.
# -  Responde en inglés
# - Proporcione dos resultados:
#   1. REASON: Una breve explicación de si el PASSAGE responde a la  QUESTION.
#   2. ANSWER: "Yes" or "No".
#
# #### TU TAREA ####
# QUESTION: Should you breastfeed your baby if you have HIV?
# PASSAGE: Las recomendaciones se han revisado para tener en cuenta también las necesidades de los lactantes cuyas madres están infectadas por el VIH. Los tratamientos antiretrovíricos actuales permiten que estos niños tengan una lactancia exclusivamente materna hasta los 6 meses y sigan recibiendo lactancia materna al menos hasta los 12 meses con un riesgo significativamente menor de transmisión del VIH.
#
#
# ...

# %%
r, _ = prompter.prompt(prompt_t)
print(r)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 r, _ = prompter.prompt(prompt_t)
#       2 print(r)
#
# File ~/mind/src/mind/prompter/prompter.py:293, in Prompter.prompt(self, question, system_prompt_template_path, use_context, temperature, dry_run)
#     290 params_tuple = tuple(sorted(self.params.items()))
#     292 #print("Cache key:", hash_input(system_prompt_template, question, self.model_type, self.backend, params_tuple, self.context, use_context))
# --> 293 cached_data = self._cached_prompt_impl(
#     294     template=system_prompt_template,
#     295     question=question,
#     296     model_type=self.model_type,
#     297     backend=self.backend,
#     298     params=params_tuple,
#     299     context=self.context if use_context else None,
#     300     use_context=use_context,
#     301 )
# ...
